# %%
import requests, zipfile, io, sys
import pandas as pd

# %% [markdown]
# # Data Collection & EDA

# %% [markdown]
# __a. Lines Information__

# %%
header = {'api_key': '29f3d28264f8450f96506480de622a24'}
response = requests.get("https://api.wmata.com/Rail.svc/json/jLines", headers=header) 
response.status_code
# Out:
# 200

# %%
lines_json = response.json()
lines_arr = lines_json["Lines"]
lines = pd.DataFrame.from_records(lines_arr)
lines
# Out:
#   LineCode DisplayName StartStationCode EndStationCode InternalDestination1  \
# 0       BL        Blue              J03            G05
# 1       GR       Green              F11            E10
# 2       OR      Orange              K08            D13
# 3       RD         Red              A15            B11                  A11
# 4       SV      Silver              N06            G05
# 5       YL      Yellow              C15            E06                  E01
#
#   InternalDestination2
# 0
# 1
# 2
# 3                  B08
# 4
# 5

# %% [markdown]
# __b. Stations Information__

# %%
r = requests.get("https://api.wmata.com/Rail.svc/json/jStations", headers=header) 
r.status_code
# Out:
# 200

# %%
stations_json = r.json()
stations_arr = stations_json["Stations"]
stations = pd.DataFrame.from_records(stations_arr)
stations.to_csv('out.csv')

# %% [markdown]
# The address data is nested in a dict. Let's give each field in the dict a new column.

# %%
addresses = stations['Address'].apply(pd.Series)
stations = pd.concat([stations.drop(['Address'], axis=1), addresses], axis=1)
stations[:1]
# Out:
#   Code          Name StationTogether1 StationTogether2 LineCode1 LineCode2  \
# 0  A01  Metro Center              C01                         RD      None
#
#   LineCode3 LineCode4        Lat        Lon           Street        City  \
# 0      None      None  38.898303 -77.028099  607 13th St. NW  Washington
#
#   State    Zip
# 0    DC  20005

# %%
stations[stations['StationTogether1'] != '']
# Out:
#    Code                  Name StationTogether1 StationTogether2 LineCode1  \
# 0   A01          Metro Center              C01                         RD
# 15  B01  Gallery Pl-Chinatown              F01                         RD
# 20  B06           Fort Totten              E06                         RD
# 27  C01          Metro Center              A01                         BL
# 44  D03        L'Enfant Plaza              F03                         BL
# 60  E06           Fort Totten              B06                         GR
# 65  F01  Gallery Pl-Chinatown              B01                         GR
# 67  F03        L'Enfant Plaza              D03                         GR
#
#    LineCode2 LineCode3 LineCode4        Lat        Lon  \
# 0       None      None      None  38.898303 -77.028099
# 15      None      None      None  38.898340 -77.021851
# 20      None      None      None  38.951777 -77.002174
# 27        OR        SV      None  38.898303 -77.028099
# 44        OR        SV      None  38.884775 -77.021964
# 60        YL      None      None  38.951777 -77.002174
# 65        YL      None      None  38.898340 -77.021851
# 67        YL      None      None  38.884775 -77.021964
#
#                     Street        City State    Zip
# 0          607 13th St. NW  Washington    DC  20005
# 15            630 H St. NW  Washington    DC  20001
# 20      550 Galloway St NE  Washington    DC  20011
# 27         607 13th St. NW  Washington    DC  20005
# 44  600 Maryland Avenue SW  Washington    DC  20024
# 60      550 Galloway St NE  Washington    DC  20011
# 65            630 H St. NW  Washington    DC  20001
# 67  600 Maryland Avenue SW  Washington    DC  20024

# %%
stations[stations['StationTogether1'] != ''].shape
# Out:
# (8, 14)

# %% [markdown]
# There are 8 stations with more than one entrance.

# %%
stations.shape
# Out:
# (102, 14)

# %% [markdown]
# Note that there are 102 metro stations respresented in our dataset.

# %% [markdown]
# __c. Station to Station__

# %%
r = requests.get("https://api.wmata.com/Rail.svc/json/jSrcStationToDstStationInfo", headers=header) 
r.status_code
# Out:
# 200

# %%
station_to_station_json = r.json()
station_to_station_arr = station_to_station_json["StationToStationInfos"]
station_to_station = pd.DataFrame.from_records(station_to_station_arr)
station_to_station.head()
# Out:
#   SourceStation DestinationStation  CompositeMiles  RailTime  \
# 0           A01                A02            0.75         2
# 1           A01                A03            1.23         4
# 2           A01                A04            2.40         6
# 3           A01                A05            3.10         9
# 4           A01                A06            3.73        11
#
#                                             RailFare
# 0  {'PeakTime': 2.0, 'OffPeakTime': 2.0, 'SeniorD...
# 1  {'PeakTime': 2.25, 'OffPeakTime': 2.25, 'Senio...
# 2  {'PeakTime': 2.25, 'OffPeakTime': 2.25, 'Senio...
# 3  {'PeakTime': 2.3, 'OffPeakTime': 2.3, 'SeniorD...
# 4  {'PeakTime': 2.6, 'OffPeakTime': 2.5, 'SeniorD...

# %% [markdown]
# The fare data is nested in a dict with three fields: _OffPeakTime_, _PeakTime_, and _SeniorDisabled_. Let's put them in their own columns.

# %%
fares = station_to_station['RailFare'].apply(pd.Series)
station_to_station = pd.concat([station_to_station.drop(['RailFare'], axis=1), fares], axis=1)
station_to_station.head()
# Out:
#   SourceStation DestinationStation  CompositeMiles  RailTime  PeakTime  \
# 0           A01                A02            0.75         2      2.00
# 1           A01                A03            1.23         4      2.25
# 2           A01                A04            2.40         6      2.25
# 3           A01                A05            3.10         9      2.30
# 4           A01                A06            3.73        11      2.60
#
#    OffPeakTime  SeniorDisabled
# 0         2.00            1.10
# 1         2.25            1.10
# 2         2.25            1.10
# 3         2.30            1.15
# 4         2.50            1.25

# %% [markdown]
# Note that there are 10,300 rows for station to station info. The station to station info should have a row for each combination of stations, including both directions separately (routes __A -> B__ _and_ __B -> A__ should both be counted because their fares/times may differ). The number of combinations of 2 stations out of 102 total is calculated with the combinations formula (nCr), and comes out to 5151, which is half of 10,300 (minus 2 missing rows for combinations of the same station (A -> A)).

# %% [markdown]
# So 10,300 is the number of possible combinations of stations in the system, including _some_ of the combinations of a station and itself. Note that there is a real fare for "routes" from a station to itself, meaning that users are actually charged for entering and then exiting the same station. In 2016, WMATA implemented a grace period that would refund users if they leave the station in 15 minutes.

# %% [markdown]
# __d. GTFS Static__

# %% [markdown]
# The GTFS (General Transit Feed Specification) is an open standard data format used by WMATA to store its more in-depth transit data. We can retrieve data such as real-time ridership, train locations, speeds, and service alerts, which is the stuff we'll need to do some real data science.

# %% [markdown]
# First I'm trying to get the static (non real-time) version of the data. It is updated daily, so still plenty useful for analysis

# %%
response = requests.get("https://api.wmata.com/gtfs/rail-gtfs-static.zip", headers=header) 
response.status_code
# Out:
# 200

# %%
z = zipfile.ZipFile(io.BytesIO(response.content))
z.extractall(path='./gtfs_static') # extract the data to './gtfs_static'

# %%
trips = pd.read_csv('./gtfs_static/trips.txt')
stops = pd.read_csv('./gtfs_static/stops.txt')

# %% [markdown]
# __e. GTFS Real Time__

# %%
import google.protobuf
import gtfs_realtime_pb2 as rt

# %% [markdown]
# This is a protocol format file we need to set up our system to be able to read the data from the protocol buffer file. I'll compile the protocol buffer into the CWD

# %%
response = requests.get("https://gtfs.org/realtime/gtfs-realtime.proto") 
# !protoc -I=. --python_out=. ./gtfs-realtime.proto

# %% [markdown]
# __Get Vehicle Positions__ - the real-time lattitude, longitude, bearing, occupancy status and more for each train in the system

# %%
response = requests.get("https://api.wmata.com/gtfs/rail-gtfsrt-vehiclepositions.pb", headers=header) 
positions_pb = rt.FeedMessage()
positions_pb.ParseFromString(response.content)
positions_pb
# Out:
# header {
#   gtfs_realtime_version: "2.0"
#   incrementality: FULL_DATASET
#   timestamp: 1721322043
# }
# entity {
#   id: "0"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952135_19920"
#       start_time: "13:03:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.1209068
#       longitude: -77.1653671
#       bearing: 145
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_A15_C"
#     vehicle {
#       id: "260"
#       label: "113"
#       license_plate: "8_3229-3228.3278-3279.3136-3137.3218-3219"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "1"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952229_19920"
#       start_time: "12:33:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9422798
#       longitude: -77.0624847
#       bearing: 156
#     }
#     current_stop_sequence: 10
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_A06_C"
#     vehicle {
#       id: "259"
#       label: "103"
#       license_plate: "8_7054-7055.7001-7000.7696-7697.7031-7030"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "2"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952230_19920"
#       start_time: "12:57:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.0842361
#       longitude: -77.1462479
#       bearing: 138
#     }
#     current_stop_sequence: 2
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_A14_C"
#     vehicle {
#       id: "254"
#       label: "111"
#       license_plate: "8_7012-7013.7091-7090.7074-7075.7077-7076"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "3"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952054_19920"
#       start_time: "12:51:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.0471268
#       longitude: -77.1124649
#       bearing: 159
#     }
#     current_stop_sequence: 4
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_A12_C"
#     vehicle {
#       id: "290"
#       label: "109"
#       license_plate: "6_3284-3285.3212-3213.3283-3282"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "4"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5951951_19920"
#       start_time: "12:45:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9973297
#       longitude: -77.0967255
#       bearing: 175
#     }
#     current_stop_sequence: 6
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_A10_C"
#     vehicle {
#       id: "280"
#       label: "107"
#       license_plate: "8_7042-7043.7085-7084.7040-7041.7081-7080"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "5"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952134_19920"
#       start_time: "12:21:27"
#       start_date: "20240718"
#       schedule_relationship: DUPLICATED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.90588
#       longitude: -77.0413361
#       bearing: 156
#     }
#     current_stop_sequence: 13
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_A03_1"
#     vehicle {
#       id: "009"
#       label: "101"
#       license_plate: "8_7596-7597.7219-7218.7258-7259.7695-7694"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "6"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952047_19920"
#       start_time: "12:39:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9593658
#       longitude: -77.0850906
#       bearing: 158
#     }
#     current_stop_sequence: 8
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_A08_C"
#     vehicle {
#       id: "273"
#       label: "105"
#       license_plate: "8_7540-7541.7187-7186.7460-7461.7703-7702"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "7"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5951968_19920"
#       start_time: "13:01:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.975071
#       longitude: -77.0175095
#       bearing: 157
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_B07_C"
#     vehicle {
#       id: "317"
#       label: "122"
#       license_plate: "8_7002-7003.7059-7058.7026-7027.7079-7078"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "8"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952115_19920"
#       start_time: "12:43:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8983421
#       longitude: -77.0275574
#       bearing: 270
#     }
#     current_stop_sequence: 9
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_A01_2"
#     vehicle {
#       id: "300"
#       label: "116"
#       license_plate: "6_3260-3261.3209-3208.3225-3224"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "9"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952260_19920"
#       start_time: "12:55:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9284515
#       longitude: -76.9938812
#       bearing: 176
#     }
#     current_stop_sequence: 3
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_B05_C"
#     vehicle {
#       id: "311"
#       label: "120"
#       license_plate: "8_3275-3274.3161-3160.3129-3128.3171-3170"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "10"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952086_19920"
#       start_time: "12:49:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8965454
#       longitude: -77.0078812
#       bearing: 196
#     }
#     current_stop_sequence: 6
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_B03_C"
#     vehicle {
#       id: "348"
#       label: "118"
#       license_plate: "6_3180-3181.3246-3247.3241-3240"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "11"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952259_19920"
#       start_time: "12:31:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9489098
#       longitude: -77.0796127
#       bearing: 338
#     }
#     current_stop_sequence: 15
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_A07_C"
#     vehicle {
#       id: "293"
#       label: "110"
#       license_plate: "8_3175-3174.3197-3196.3151-3150.3263-3262"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "12"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5951958_19920"
#       start_time: "12:25:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9832916
#       longitude: -77.0935898
#       bearing: 343
#     }
#     current_stop_sequence: 17
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_A09_C"
#     vehicle {
#       id: "286"
#       label: "108"
#       license_plate: "6_3223-3222.3159-3158.3236-3237"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "13"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5951957_19920"
#       start_time: "12:19:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 39.0349655
#       longitude: -77.1066132
#       bearing: 339
#     }
#     current_stop_sequence: 19
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_A11_C"
#     vehicle {
#       id: "282"
#       label: "106"
#       license_plate: "8_3144-3145.3259-3258.3168-3169.3187-3186"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "14"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952021_19920"
#       start_time: "12:13:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 39.0637741
#       longitude: -77.1224365
#       bearing: 322
#     }
#     current_stop_sequence: 21
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_A13_C"
#     vehicle {
#       id: "276"
#       label: "104"
#       license_plate: "8_3250-3251.3220-3221.3074-3075.3148-3149"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "15"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR409"
#       start_time: "12:54:01"
#       start_date: "20240718"
#       schedule_relationship: ADDED
#       route_id: "NR"
#       direction_id: 1
#     }
#     position {
#       latitude: 39.0808067
#       longitude: -77.1420822
#       bearing: 318
#     }
#     current_stop_sequence: 22
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_A13_C"
#     vehicle {
#       id: "060"
#       label: "718"
#       license_plate: "6_3276-3277.3230-3231"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "16"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952258_19920"
#       start_time: "12:07:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 39.1173706
#       longitude: -77.1625366
#       bearing: 328
#     }
#     current_stop_sequence: 22
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_A14_C"
#     vehicle {
#       id: "263"
#       label: "102"
#       license_plate: "6_3255-3254.3123-3122.3266-3267"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "17"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952134_19920"
#       start_time: "12:21:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8983498
#       longitude: -77.0212326
#       bearing: 92
#     }
#     current_stop_sequence: 16
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_B01_1"
#     vehicle {
#       id: "341"
#       label: "149"
#       license_plate: "8_3245-3244.3126-3127.3227-3226.3166-3167"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "18"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5951953_19920"
#       start_time: "12:27:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.89748
#       longitude: -77.0074
#       bearing: 16
#     }
#     current_stop_sequence: 18
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_B03_C"
#     vehicle {
#       id: "477"
#       label: "147"
#       license_plate: "8_"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "19"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952061_19920"
#       start_time: "12:15:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9209
#       longitude: -76.9958725
#       bearing: 18
#     }
#     current_stop_sequence: 20
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_B04_C"
#     vehicle {
#       id: "334"
#       label: "145"
#       license_plate: "8_7018-7019.7007-7006.7086-7087.7065-7064"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "20"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR372"
#       start_time: "11:57:19"
#       start_date: "20240718"
#       schedule_relationship: ADDED
#       route_id: "NR"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9800873
#       longitude: -77.0204315
#       bearing: 337
#     }
#     timestamp: 1721322043
#     vehicle {
#       id: "173"
#       label: "GC01"
#       license_plate: "0_"
#     }
#   }
# }
# entity {
#   id: "21"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR372"
#       start_time: "11:35:49"
#       start_date: "20240718"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9926338
#       longitude: -77.0300446
#       bearing: 319
#     }
#     timestamp: 1721322043
#     vehicle {
#       id: "372"
#       label: "PM57"
#       license_plate: "0_"
#     }
#   }
# }
# entity {
#   id: "22"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR409"
#       start_time: "10:04:39"
#       start_date: "20240718"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 1
#     }
#     position {
#       latitude: 39.0021858
#       longitude: -77.0399551
#       bearing: 178
#     }
#     timestamp: 1721322043
#     vehicle {
#       id: "409"
#       label: ""
#       license_plate: "0_"
#     }
#   }
# }
# entity {
#   id: "23"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR405"
#       start_time: "11:33:39"
#       start_date: "20240718"
#       schedule_relationship: ADDED
#       route_id: "NR"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.0149
#       longitude: -77.0432053
#       bearing: 349
#     }
#     current_stop_sequence: 1
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_B09_C"
#     vehicle {
#       id: "480"
#       label: ""
#       license_plate: "0_"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "24"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR405"
#       start_time: "08:01:25"
#       start_date: "20240718"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.0201111
#       longitude: -77.0442505
#       bearing: 342
#     }
#     current_stop_sequence: 1
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_B09_C"
#     vehicle {
#       id: "404"
#       label: ""
#       license_plate: "0_"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "25"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217964_19920"
#       start_time: "13:01:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8775215
#       longitude: -77.2724457
#       bearing: 78
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_K08_C"
#     vehicle {
#       id: "503"
#       label: "941"
#       license_plate: "6_3005-3004.3106-3107.3038-3039"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "26"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217965_19920"
#       start_time: "13:13:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8774147
#       longitude: -77.2737656
#       bearing: 78
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_K08_C"
#     vehicle {
#       id: "249"
#       label: "943"
#       license_plate: "6_7668-7669.7628-7629.7125-7124"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "27"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218202_19920"
#       start_time: "13:02:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.7660332
#       longitude: -77.1689682
#       bearing: 62
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_J03_C"
#     vehicle {
#       id: "328"
#       label: "439"
#       license_plate: "8_7456-7457.7253-7252.7342-7343.7327-7326"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "28"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216870_19920"
#       start_time: "12:11:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8824539
#       longitude: -77.1072617
#       bearing: 87
#     }
#     current_stop_sequence: 13
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_K04_1"
#     vehicle {
#       id: "274"
#       label: "635"
#       license_plate: "8_7386-7387.7247-7246.7572-7573.7321-7320"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "29"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216785_19920"
#       start_time: "12:26:13"
#       start_date: "20240718"
#       schedule_relationship: DUPLICATED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9397316
#       longitude: -77.2711792
#       bearing: 133
#     }
#     current_stop_sequence: 7
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_N06_C"
#     vehicle {
#       id: "296"
#       label: "639"
#       license_plate: "6_7302-7303.7354-7355.7205-7204"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "30"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216884_19920"
#       start_time: "11:59:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9006348
#       longitude: -77.0287628
#       bearing: 140
#     }
#     current_stop_sequence: 20
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_C02_1"
#     vehicle {
#       id: "333"
#       label: "633"
#       license_plate: "6_3031-3030.3265-3264.3116-3117"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "31"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216882_19920"
#       start_time: "12:49:31"
#       start_date: "20240718"
#       schedule_relationship: DUPLICATED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9936867
#       longitude: -77.4674759
#       bearing: 94
#     }
#     current_stop_sequence: 1
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_N12_C"
#     vehicle {
#       id: "338"
#       label: "643"
#       license_plate: "8_7316-7317.7349-7348.7184-7185.7485-7484"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "32"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218201_19920"
#       start_time: "12:38:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8579636
#       longitude: -77.0469208
#       bearing: 295
#     }
#     current_stop_sequence: 6
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_C10_1"
#     vehicle {
#       id: "371"
#       label: "435"
#       license_plate: "8_7478-7479.7483-7482.7188-7189.7427-7426"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "33"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217963_19920"
#       start_time: "12:49:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8810806
#       longitude: -77.1423264
#       bearing: 114
#     }
#     current_stop_sequence: 4
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_K05_C"
#     vehicle {
#       id: "434"
#       label: "939"
#       license_plate: "6_7190-7191.7621-7620.7583-7582"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "34"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218189_19920"
#       start_time: "12:26:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9013214
#       longitude: -77.0374
#       bearing: 90
#     }
#     current_stop_sequence: 13
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_C03_1"
#     vehicle {
#       id: "436"
#       label: "433"
#       license_plate: "6_7528-7529.7282-7283.7493-7492"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "35"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218205_19920"
#       start_time: "12:50:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8048744
#       longitude: -77.0642853
#       bearing: 70
#     }
#     current_stop_sequence: 2
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_J02_C"
#     vehicle {
#       id: "437"
#       label: "435"
#       license_plate: "6_3177-3176.3153-3152.3199-3198"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "36"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216857_19920"
#       start_time: "12:23:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9049492
#       longitude: -77.1879959
#       bearing: 191
#     }
#     current_stop_sequence: 11
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_N01_C"
#     vehicle {
#       id: "470"
#       label: "637"
#       license_plate: "8_7590-7591.7589-7588.7276-7277.7265-7264"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "37"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216882_19920"
#       start_time: "12:59:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9650383
#       longitude: -77.4495621
#       bearing: 219
#     }
#     current_stop_sequence: 2
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_N11_C"
#     vehicle {
#       id: "306"
#       label: "724"
#       license_plate: "8_7714-7715.7549-7548.7558-7559.7373-7372"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "38"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR008"
#       start_time: "12:42:29"
#       start_date: "20240718"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.886158
#       longitude: -77.096611
#       bearing: 59
#     }
#     current_stop_sequence: 6
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_K03_1"
#     vehicle {
#       id: "008"
#       label: "824"
#       license_plate: "6_7130-7131.7459-7458"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "39"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216785_19920"
#       start_time: "12:47:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9562263
#       longitude: -77.4026718
#       bearing: 112
#     }
#     current_stop_sequence: 4
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_N09_C"
#     vehicle {
#       id: "049"
#       label: "641"
#       license_plate: "8_7214-7215.7113-7112.7284-7285.7133-7132"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "40"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217962_19920"
#       start_time: "12:44:53"
#       start_date: "20240718"
#       schedule_relationship: DUPLICATED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8960381
#       longitude: -77.0707626
#       bearing: 358
#     }
#     current_stop_sequence: 9
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_C05_1"
#     vehicle {
#       id: "319"
#       label: "937"
#       license_plate: "6_7616-7617.7329-7328.7383-7382"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "41"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216861_19920"
#       start_time: "13:02:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9005547
#       longitude: -76.8447113
#       bearing: 226
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_G05_C"
#     vehicle {
#       id: "257"
#       label: "644"
#       license_plate: "6_7472-7473.7134-7135.7633-7632"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "42"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218183_19920"
#       start_time: "12:54:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8867607
#       longitude: -76.8989792
#       bearing: 270
#     }
#     current_stop_sequence: 3
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_G03_C"
#     vehicle {
#       id: "237"
#       label: "438"
#       license_plate: "6_7742-7743.7651-7650.7279-7278"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "43"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216879_19920"
#       start_time: "12:38:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.885128
#       longitude: -77.0159531
#       bearing: 270
#     }
#     current_stop_sequence: 10
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_D04_C"
#     vehicle {
#       id: "243"
#       label: "640"
#       license_plate: "8_7436-7437.7403-7402.7544-7545.7623-7622"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "44"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218032_19920"
#       start_time: "12:58:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.933548
#       longitude: -76.8913116
#       bearing: 229
#     }
#     current_stop_sequence: 2
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_D12_C"
#     vehicle {
#       id: "246"
#       label: "946"
#       license_plate: "6_7424-7425.7509-7508.7701-7700"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "45"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218030_19920"
#       start_time: "12:34:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8849068
#       longitude: -77.0220795
#       bearing: 270
#     }
#     current_stop_sequence: 11
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_D03_C"
#     vehicle {
#       id: "303"
#       label: "942"
#       license_plate: "6_7268-7269.7275-7274.7717-7716"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "46"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218179_19920"
#       start_time: "12:30:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8938332
#       longitude: -77.0280685
#       bearing: 0
#     }
#     current_stop_sequence: 13
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_D01_C"
#     vehicle {
#       id: "429"
#       label: "434"
#       license_plate: "8_7718-7719.7137-7136.7740-7741.7525-7524"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "47"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218031_19920"
#       start_time: "12:46:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8869247
#       longitude: -76.9771423
#       bearing: 180
#     }
#     current_stop_sequence: 6
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_D08_C"
#     vehicle {
#       id: "413"
#       label: "944"
#       license_plate: "8_7208-7209.7315-7314.7362-7363.7069-7068"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "48"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216876_19920"
#       start_time: "12:50:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8961945
#       longitude: -76.9526367
#       bearing: 281
#     }
#     current_stop_sequence: 5
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_G01_C"
#     vehicle {
#       id: "416"
#       label: "642"
#       license_plate: "8_7404-7405.7379-7378.7736-7737.7675-7674"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "49"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218178_19920"
#       start_time: "12:42:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.881321
#       longitude: -76.9855804
#       bearing: 270
#     }
#     current_stop_sequence: 7
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_D07_C"
#     vehicle {
#       id: "489"
#       label: "436"
#       license_plate: "8_7706-7707.7207-7206.7352-7353.7345-7344"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "50"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216885_19920"
#       start_time: "12:26:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8983727
#       longitude: -77.0708
#       bearing: 198
#     }
#     current_stop_sequence: 17
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_C04_C"
#     vehicle {
#       id: "310"
#       label: "638"
#       license_plate: "8_7556-7557.7193-7192.7686-7687.7399-7398"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "51"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217255_19920"
#       start_time: "12:51:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8434258
#       longitude: -77.0495148
#       bearing: 347
#     }
#     current_stop_sequence: 5
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_C11_1"
#     vehicle {
#       id: "314"
#       label: "329"
#       license_plate: "6_7536-7537.7670-7671.7561-7560"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "52"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216791_19920"
#       start_time: "12:43:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8618507
#       longitude: -77.059494
#       bearing: 6
#     }
#     current_stop_sequence: 8
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_C08_1"
#     vehicle {
#       id: "442"
#       label: "327"
#       license_plate: "6_"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "53"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216786_19920"
#       start_time: "12:59:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8003616
#       longitude: -77.0711136
#       bearing: 43
#     }
#     current_stop_sequence: 2
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_C14_1"
#     vehicle {
#       id: "262"
#       label: "331"
#       license_plate: "8_7396-7397.7261-7260.7476-7477.7155-7154"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "54"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216831_19920"
#       start_time: "12:52:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8781624
#       longitude: -77.0364075
#       bearing: 227
#     }
#     current_stop_sequence: 4
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_F03_2"
#     vehicle {
#       id: "307"
#       label: "334"
#       license_plate: "6_3082-3083.3115-3114.3067-3066"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "55"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218171_19920"
#       start_time: "12:18:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.869236
#       longitude: -77.0541611
#       bearing: 226
#     }
#     current_stop_sequence: 20
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_C07_2"
#     vehicle {
#       id: "339"
#       label: "432"
#       license_plate: "6_7498-7499.7438-7439.7401-7400"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "56"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216812_19920"
#       start_time: "12:44:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8534813
#       longitude: -77.0441437
#       bearing: 162
#     }
#     current_stop_sequence: 8
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_C10_2"
#     vehicle {
#       id: "291"
#       label: "332"
#       license_plate: "6_"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "57"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR469"
#       start_time: "12:58:29"
#       start_date: "20240718"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8161697
#       longitude: -77.05233
#       bearing: 209
#     }
#     current_stop_sequence: 1
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_C11_2"
#     vehicle {
#       id: "469"
#       label: "599"
#       license_plate: "6_3089-3088.2016-2017"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "58"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217333_19920"
#       start_time: "12:36:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8119316
#       longitude: -77.0553284
#       bearing: 209
#     }
#     current_stop_sequence: 10
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_C12_C"
#     vehicle {
#       id: "484"
#       label: "330"
#       license_plate: "6_3084-3085.3042-3043.3232-3233"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "59"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218180_19920"
#       start_time: "12:06:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8066521
#       longitude: -77.0610199
#       bearing: 229
#     }
#     current_stop_sequence: 26
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_C13_C"
#     vehicle {
#       id: "468"
#       label: "430"
#       license_plate: "6_7652-7653.7710-7711.7173-7172"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "60"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216830_19920"
#       start_time: "12:28:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.79842
#       longitude: -77.0735321
#       bearing: 223
#     }
#     current_stop_sequence: 12
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_C14_2"
#     vehicle {
#       id: "302"
#       label: "328"
#       license_plate: "8_7368-7369.7361-7360.7658-7659.7619-7618"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "61"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217961_19920"
#       start_time: "12:25:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8884468
#       longitude: -77.0286407
#       bearing: 166
#     }
#     current_stop_sequence: 15
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_D02_1"
#     vehicle {
#       id: "267"
#       label: "935"
#       license_plate: "6_3055-3054.3091-3090.3049-3048"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "62"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218203_19920"
#       start_time: "12:14:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8850212
#       longitude: -77.0032654
#       bearing: 88
#     }
#     current_stop_sequence: 20
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_D05_C"
#     vehicle {
#       id: "298"
#       label: "431"
#       license_plate: "8_3006-3007.3079-3078.3155-3154.3073-3072"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "63"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217960_19920"
#       start_time: "12:13:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8812218
#       longitude: -76.9855804
#       bearing: 90
#     }
#     current_stop_sequence: 20
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_D07_C"
#     vehicle {
#       id: "297"
#       label: "933"
#       license_plate: "6_7502-7503.7393-7392.7609-7608"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "64"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217407_19920"
#       start_time: "12:41:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8803558
#       longitude: -77.0220642
#       bearing: 8
#     }
#     current_stop_sequence: 8
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_F04_C"
#     vehicle {
#       id: "320"
#       label: "525"
#       license_plate: "8_6170-6171.6150-6151.6031-6030.6068-6069"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "65"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216846_19920"
#       start_time: "12:57:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8501167
#       longitude: -76.944252
#       bearing: 309
#     }
#     current_stop_sequence: 2
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_F10_C"
#     vehicle {
#       id: "337"
#       label: "529"
#       license_plate: "6_7732-7733.7411-7410.7625-7624"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "66"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217254_19920"
#       start_time: "12:35:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8851242
#       longitude: -77.0218887
#       bearing: 0
#     }
#     current_stop_sequence: 10
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_F03_1"
#     vehicle {
#       id: "435"
#       label: "325"
#       license_plate: "6_7580-7581.7612-7613.7739-7738"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "67"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216845_19920"
#       start_time: "12:33:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9005966
#       longitude: -77.0218353
#       bearing: 0
#     }
#     current_stop_sequence: 11
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_F01_C"
#     vehicle {
#       id: "315"
#       label: "523"
#       license_plate: "8_7266-7267.7151-7150.7546-7547.7555-7554"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "68"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216847_19920"
#       start_time: "12:49:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8457298
#       longitude: -76.9883881
#       bearing: 329
#     }
#     current_stop_sequence: 5
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_F07_C"
#     vehicle {
#       id: "363"
#       label: "527"
#       license_plate: "8_6092-6093.6034-6035.6153-6152.6146-6147"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "69"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217374_19920"
#       start_time: "13:06:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 39.0103874
#       longitude: -76.9119186
#       bearing: 215
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_E10_C"
#     vehicle {
#       id: "255"
#       label: "536"
#       license_plate: "8_7416-7417.7335-7334.7298-7299.7147-7146"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "70"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216856_19920"
#       start_time: "12:50:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9523697
#       longitude: -76.9859467
#       bearing: 276
#     }
#     current_stop_sequence: 4
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_E07_2"
#     vehicle {
#       id: "325"
#       label: "532"
#       license_plate: "6_6011-6010.6074-6075.6100-6101"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "71"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216840_19920"
#       start_time: "12:58:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9852448
#       longitude: -76.9254913
#       bearing: 199
#     }
#     current_stop_sequence: 1
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_E10_C"
#     vehicle {
#       id: "342"
#       label: "534"
#       license_plate: "8_7692-7693.7689-7688.7494-7495.7643-7642"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "72"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217373_19920"
#       start_time: "12:42:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9316025
#       longitude: -77.0288773
#       bearing: 246
#     }
#     current_stop_sequence: 6
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_E05_C"
#     vehicle {
#       id: "364"
#       label: "530"
#       license_plate: "8_6105-6104.6160-6161.6081-6080.6117-6116"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "73"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216848_19920"
#       start_time: "12:25:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9516754
#       longitude: -77.0031738
#       bearing: 85
#     }
#     current_stop_sequence: 17
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_E06_C"
#     vehicle {
#       id: "382"
#       label: "521"
#       license_plate: "6_7552-7553.7648-7649.7601-7600"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "74"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217406_19920"
#       start_time: "12:17:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.965271
#       longitude: -76.9564285
#       bearing: 90
#     }
#     current_stop_sequence: 19
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_E08_1"
#     vehicle {
#       id: "448"
#       label: "519"
#       license_plate: "6_6157-6156.6079-6078.6082-6083"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "75"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216855_19920"
#       start_time: "12:34:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8932266
#       longitude: -77.0219727
#       bearing: 180
#     }
#     current_stop_sequence: 12
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_F02_C"
#     vehicle {
#       id: "301"
#       label: "528"
#       license_plate: "6_6046-6047.6140-6141.6013-6012"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "76"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216851_19920"
#       start_time: "12:26:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8632736
#       longitude: -76.9956284
#       bearing: 167
#     }
#     current_stop_sequence: 16
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_F06_C"
#     vehicle {
#       id: "450"
#       label: "526"
#       license_plate: "6_7250-7251.7198-7199.7531-7530"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "77"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217372_19920"
#       start_time: "12:18:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8510704
#       longitude: -76.9565887
#       bearing: 80
#     }
#     current_stop_sequence: 19
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_F09_C"
#     vehicle {
#       id: "292"
#       label: "524"
#       license_plate: "6_7228-7229.7123-7122.7243-7242"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "78"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216853_19920"
#       start_time: "12:10:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.844635
#       longitude: -76.9329147
#       bearing: 139
#     }
#     current_stop_sequence: 20
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_F10_C"
#     vehicle {
#       id: "272"
#       label: "522"
#       license_plate: "6_7576-7577.7679-7678.7587-7586"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "79"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216887_19920"
#       start_time: "11:36:06"
#       start_date: "20240718"
#       schedule_relationship: DUPLICATED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8928032
#       longitude: -76.9423752
#       bearing: 117
#     }
#     current_stop_sequence: 29
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_D08_C"
#     vehicle {
#       id: "335"
#       label: "631"
#       license_plate: "8_7308-7309.7519-7518.7602-7603.7197-7196"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "80"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218200_19920"
#       start_time: "12:02:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8897247
#       longitude: -76.9317703
#       bearing: 90
#     }
#     current_stop_sequence: 24
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_G01_C"
#     vehicle {
#       id: "258"
#       label: "429"
#       license_plate: "6_3062-3063.3098-3099.3086-3087"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "81"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216886_19920"
#       start_time: "11:27:38"
#       start_date: "20240718"
#       schedule_relationship: DUPLICATED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8912468
#       longitude: -76.8746
#       bearing: 63
#     }
#     current_stop_sequence: 32
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_G03_C"
#     vehicle {
#       id: "003"
#       label: "629"
#       license_plate: "6_3135-3134.3291-3290.3053-3052"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "82"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218173_19920"
#       start_time: "11:54:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.797924
#       longitude: -77.139061
#       bearing: 261
#     }
#     current_stop_sequence: 27
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_J02_C"
#     vehicle {
#       id: "283"
#       label: "428"
#       license_plate: "6_6149-6148.6112-6113.6166-6167"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "83"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218029_19920"
#       start_time: "12:22:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8902168
#       longitude: -77.0871277
#       bearing: 243
#     }
#     current_stop_sequence: 19
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_K01_C"
#     vehicle {
#       id: "432"
#       label: "940"
#       license_plate: "8_7684-7685.7605-7604.7656-7657.7481-7480"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "84"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216885_19920"
#       start_time: "12:27:56"
#       start_date: "20240718"
#       schedule_relationship: DUPLICATED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8853226
#       longitude: -77.0984802
#       bearing: 240
#     }
#     current_stop_sequence: 20
#     current_status: INCOMING_AT
#     timestamp: 1721322043
#     stop_id: "PF_K02_2"
#     vehicle {
#       id: "327"
#       label: "636"
#       license_plate: "6_6071-6070.6028-6029.6132-6133"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "85"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6218028_19920"
#       start_time: "12:10:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8972435
#       longitude: -77.1756821
#       bearing: 294
#     }
#     current_stop_sequence: 23
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_K05_C"
#     vehicle {
#       id: "279"
#       label: "938"
#       license_plate: "6_7140-7141.7241-7240.7223-7222"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "86"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216874_19920"
#       start_time: "12:02:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9237633
#       longitude: -77.2119446
#       bearing: 240
#     }
#     current_stop_sequence: 24
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_N01_C"
#     vehicle {
#       id: "453"
#       label: "634"
#       license_plate: "8_7626-7627.7441-7440.7238-7239.7691-7690"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "87"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216784_19920"
#       start_time: "11:50:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9478836
#       longitude: -77.3402863
#       bearing: 293
#     }
#     current_stop_sequence: 28
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_N06_C"
#     vehicle {
#       id: "251"
#       label: "632"
#       license_plate: "6_3016-3017.3046-3047.3081-3080"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "88"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216869_19920"
#       start_time: "11:38:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9616318
#       longitude: -77.4522629
#       bearing: 180
#     }
#     current_stop_sequence: 32
#     current_status: IN_TRANSIT_TO
#     timestamp: 1721322043
#     stop_id: "PF_N10_C"
#     vehicle {
#       id: "350"
#       label: "630"
#       license_plate: "8_7194-7195.7475-7474.7322-7323.7263-7262"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "89"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6217959_19920"
#       start_time: "12:01:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9480667
#       longitude: -76.8719254
#       bearing: 42
#     }
#     current_stop_sequence: 26
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_D13_C"
#     vehicle {
#       id: "422"
#       label: "905"
#       license_plate: "6_7432-7433.7384-7385.7421-7420"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "90"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6216854_19920"
#       start_time: "12:02:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8267593
#       longitude: -76.9117813
#       bearing: 129
#     }
#     current_stop_sequence: 21
#     current_status: STOPPED_AT
#     timestamp: 1721322043
#     stop_id: "PF_F11_C"
#     vehicle {
#       id: "370"
#       label: "520"
#       license_plate: "8_3027-3026.3269-3268.3020-3021.3059-3058"
#     }
#     occupancy_status: EMPTY
#   }
# }

# %% [markdown]
# __Get Trip Updates__ - any fluctuation in the timetable (delays, cancellations, changed routes)

# %%
response = requests.get("https://api.wmata.com/gtfs/rail-gtfsrt-tripupdates.pb", headers=header) 
updates_pb = rt.FeedMessage()
updates_pb.ParseFromString(response.content)
updates_pb
# Out:
# header {
#   gtfs_realtime_version: "2.0"
#   incrementality: FULL_DATASET
#   timestamp: 1721322045
# }
# entity {
#   id: "0"
#   trip_update {
#     trip {
#       trip_id: "5952135_19920"
#       start_time: "13:03:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721322180
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721322372
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721322566
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721322712
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721322869
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721323072
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721323198
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721323373
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721323490
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721323644
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721323749
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721323871
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721324016
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721324120
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721324245
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721324334
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721324435
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721324551
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721324691
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721324843
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721324979
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721325138
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721325319
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "260"
#       label: "113"
#       license_plate: "8_3229-3228.3278-3279.3136-3137.3218-3219"
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "1"
#   trip_update {
#     trip {
#       trip_id: "5952100_19920"
#       start_time: "13:09:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721322540
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721322730
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721322924
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721323070
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721323227
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721323430
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721323556
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721323731
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721323848
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721324002
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721324107
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721324229
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721324374
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721324478
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721324603
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721324692
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721324793
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721324909
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721325049
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721325201
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721325337
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721325496
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721325677
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1547340"
#       label: "115"
#       license_plate: ""
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "2"
#   trip_update {
#     trip {
#       trip_id: "5952075_19920"
#       start_time: "13:15:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721322900
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721323090
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721323284
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721323430
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721323587
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721323790
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721323916
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721324091
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721324208
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721324362
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721324467
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721324589
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721324734
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721324838
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721324963
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721325052
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721325153
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721325269
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721325409
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721325561
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721325697
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721325856
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721326037
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1547700"
#       label: "117"
#       license_plate: ""
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "3"
#   trip_update {
#     trip {
#       trip_id: "5952231_19920"
#       start_time: "13:21:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721323260
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721323450
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721323644
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721323790
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721323947
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721324150
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721324276
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721324451
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721324568
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721324722
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721324827
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721324949
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721325094
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721325198
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721325323
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721325412
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721325513
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721325629
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721325769
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721325921
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721326057
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721326216
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721326397
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1548060"
#       label: "119"
#       license_plate: ""
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "4"
#   trip_update {
#     trip {
#       trip_id: "5951959_19920"
#       start_time: "13:27:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721323620
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721323810
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721324004
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721324150
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721324307
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721324510
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721324636
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721324811
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721324928
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721325082
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721325187
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721325309
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721325454
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721325558
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721325683
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721325772
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721325873
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721325989
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721326129
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721326281
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721326417
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721326576
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721326757
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1548420"
#       label: "121"
#       license_plate: ""
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "5"
#   trip_update {
#     trip {
#       trip_id: "5951960_19920"
#       start_time: "13:33:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721323980
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721324170
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721324364
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721324510
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721324667
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721324870
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721324996
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721325171
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721325288
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721325442
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721325547
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721325669
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721325814
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721325918
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721326043
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721326132
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721326233
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721326349
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721326489
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721326641
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721326777
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721326936
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721327117
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1548780"
#       label: "123"
#       license_plate: ""
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "6"
#   trip_update {
#     trip {
#       trip_id: "5952136_19920"
#       start_time: "13:39:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721324340
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721324530
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721324724
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721324870
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721325027
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721325230
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721325356
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721325531
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721325648
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721325802
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721325907
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721326029
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721326174
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721326278
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721326403
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721326492
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721326593
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721326709
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721326849
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721327001
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721327137
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721327296
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721327477
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1549140"
#       label: "125"
#       license_plate: ""
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "7"
#   trip_update {
#     trip {
#       trip_id: "5952229_19920"
#       start_time: "12:33:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721320368
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721320618
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721320831
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721321114
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721321268
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721321477
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721321607
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721321780
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721321892
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721322042
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721322091
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721322213
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721322358
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721322462
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721322587
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721322676
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721322777
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721322893
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721323033
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721323185
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721323321
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721323480
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721323661
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "259"
#       label: "103"
#       license_plate: "8_7054-7055.7001-7000.7696-7697.7031-7030"
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "8"
#   trip_update {
#     trip {
#       trip_id: "5952230_19920"
#       start_time: "12:57:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721321805
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721322045
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721322215
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721322361
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721322518
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721322721
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721322847
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721323022
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721323139
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721323293
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721323398
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721323520
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721323665
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721323769
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721323894
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721323983
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721324084
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721324200
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721324340
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721324492
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721324628
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721324787
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721324968
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "254"
#       label: "111"
#       license_plate: "8_7012-7013.7091-7090.7074-7075.7077-7076"
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "9"
#   trip_update {
#     trip {
#       trip_id: "5952054_19920"
#       start_time: "12:51:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721321443
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721321724
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721321949
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721322045
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721322179
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721322382
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721322508
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721322683
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721322800
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721322954
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721323059
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721323181
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721323326
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721323430
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721323555
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721323644
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721323745
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721323861
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721324001
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721324153
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721324289
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721324448
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721324629
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "290"
#       label: "109"
#       license_plate: "6_3284-3285.3212-3213.3283-3282"
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "10"
#   trip_update {
#     trip {
#       trip_id: "5951951_19920"
#       start_time: "12:45:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721321105
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721321339
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721321530
#         uncertainty: 0
#       }
# ...
#         uncertainty: 0
#       }
#       stop_id: "PF_N06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 29
#       arrival {
#         time: 1721322914
#         uncertainty: 0
#       }
#       stop_id: "PF_N07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 30
#       arrival {
#         time: 1721323071
#         uncertainty: 0
#       }
#       stop_id: "PF_N08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 31
#       arrival {
#         time: 1721323261
#         uncertainty: 0
#       }
#       stop_id: "PF_N09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 32
#       arrival {
#         time: 1721323488
#         uncertainty: 0
#       }
#       stop_id: "PF_N10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 33
#       arrival {
#         time: 1721323818
#         uncertainty: 0
#       }
#       stop_id: "PF_N11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 34
#       arrival {
#         time: 1721324057
#         uncertainty: 0
#       }
#       stop_id: "PF_N12_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "453"
#       label: "634"
#       license_plate: "8_7626-7627.7441-7440.7238-7239.7691-7690"
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "136"
#   trip_update {
#     trip {
#       trip_id: "6216784_19920"
#       start_time: "11:50:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721317805
#         uncertainty: 0
#       }
#       stop_id: "PF_G05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721318001
#         uncertainty: 0
#       }
#       stop_id: "PF_G04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721318210
#         uncertainty: 0
#       }
#       stop_id: "PF_G03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721318341
#         uncertainty: 0
#       }
#       stop_id: "PF_G02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721318510
#         uncertainty: 0
#       }
#       stop_id: "PF_G01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721318774
#         uncertainty: 0
#       }
#       stop_id: "PF_D08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721318898
#         uncertainty: 0
#       }
#       stop_id: "PF_D07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721319068
#         uncertainty: 0
#       }
#       stop_id: "PF_D06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721319172
#         uncertainty: 0
#       }
#       stop_id: "PF_D05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721319274
#         uncertainty: 0
#       }
#       stop_id: "PF_D04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721319359
#         uncertainty: 0
#       }
#       stop_id: "PF_D03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721319453
#         uncertainty: 0
#       }
#       stop_id: "PF_D02_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721319540
#         uncertainty: 0
#       }
#       stop_id: "PF_D01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721319629
#         uncertainty: 0
#       }
#       stop_id: "PF_C01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721319732
#         uncertainty: 0
#       }
#       stop_id: "PF_C02_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721319822
#         uncertainty: 0
#       }
#       stop_id: "PF_C03_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721319934
#         uncertainty: 0
#       }
#       stop_id: "PF_C04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721320090
#         uncertainty: 0
#       }
#       stop_id: "PF_C05_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721320289
#         uncertainty: 0
#       }
#       stop_id: "PF_K01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721320384
#         uncertainty: 0
#       }
#       stop_id: "PF_K02_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721320473
#         uncertainty: 0
#       }
#       stop_id: "PF_K03_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721320574
#         uncertainty: 0
#       }
#       stop_id: "PF_K04_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721320806
#         uncertainty: 0
#       }
#       stop_id: "PF_K05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 24
#       arrival {
#         time: 1721321221
#         uncertainty: 0
#       }
#       stop_id: "PF_N01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 25
#       arrival {
#         time: 1721321332
#         uncertainty: 0
#       }
#       stop_id: "PF_N02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 26
#       arrival {
#         time: 1721321460
#         uncertainty: 0
#       }
#       stop_id: "PF_N03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 27
#       arrival {
#         time: 1721321587
#         uncertainty: 0
#       }
#       stop_id: "PF_N04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 28
#       arrival {
#         time: 1721322045
#         uncertainty: 0
#       }
#       stop_id: "PF_N06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 29
#       arrival {
#         time: 1721322169
#         uncertainty: 0
#       }
#       stop_id: "PF_N07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 30
#       arrival {
#         time: 1721322326
#         uncertainty: 0
#       }
#       stop_id: "PF_N08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 31
#       arrival {
#         time: 1721322516
#         uncertainty: 0
#       }
#       stop_id: "PF_N09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 32
#       arrival {
#         time: 1721322743
#         uncertainty: 0
#       }
#       stop_id: "PF_N10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 33
#       arrival {
#         time: 1721323073
#         uncertainty: 0
#       }
#       stop_id: "PF_N11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 34
#       arrival {
#         time: 1721323312
#         uncertainty: 0
#       }
#       stop_id: "PF_N12_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "251"
#       label: "632"
#       license_plate: "6_3016-3017.3046-3047.3081-3080"
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "137"
#   trip_update {
#     trip {
#       trip_id: "6216869_19920"
#       start_time: "11:38:00"
#       start_date: "20240718"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1721317077
#         uncertainty: 0
#       }
#       stop_id: "PF_G05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1721317238
#         uncertainty: 0
#       }
#       stop_id: "PF_G04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1721317395
#         uncertainty: 0
#       }
#       stop_id: "PF_G03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1721317511
#         uncertainty: 0
#       }
#       stop_id: "PF_G02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1721317666
#         uncertainty: 0
#       }
#       stop_id: "PF_G01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1721317930
#         uncertainty: 0
#       }
#       stop_id: "PF_D08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1721318046
#         uncertainty: 0
#       }
#       stop_id: "PF_D07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1721318198
#         uncertainty: 0
#       }
#       stop_id: "PF_D06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1721318294
#         uncertainty: 0
#       }
#       stop_id: "PF_D05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1721318392
#         uncertainty: 0
#       }
#       stop_id: "PF_D04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1721318470
#         uncertainty: 0
#       }
#       stop_id: "PF_D03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1721318552
#         uncertainty: 0
#       }
#       stop_id: "PF_D02_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1721318633
#         uncertainty: 0
#       }
#       stop_id: "PF_D01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1721318709
#         uncertainty: 0
#       }
#       stop_id: "PF_C01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1721318804
#         uncertainty: 0
#       }
#       stop_id: "PF_C02_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1721318881
#         uncertainty: 0
#       }
#       stop_id: "PF_C03_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1721318985
#         uncertainty: 0
#       }
#       stop_id: "PF_C04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1721319126
#         uncertainty: 0
#       }
#       stop_id: "PF_C05_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1721319264
#         uncertainty: 0
#       }
#       stop_id: "PF_K01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1721319482
#         uncertainty: 0
#       }
#       stop_id: "PF_K02_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1721319582
#         uncertainty: 0
#       }
#       stop_id: "PF_K03_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1721319696
#         uncertainty: 0
#       }
#       stop_id: "PF_K04_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1721319937
#         uncertainty: 0
#       }
#       stop_id: "PF_K05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 24
#       arrival {
#         time: 1721320372
#         uncertainty: 0
#       }
#       stop_id: "PF_N01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 25
#       arrival {
#         time: 1721320478
#         uncertainty: 0
#       }
#       stop_id: "PF_N02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 26
#       arrival {
#         time: 1721320605
#         uncertainty: 0
#       }
#       stop_id: "PF_N03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 27
#       arrival {
#         time: 1721320726
#         uncertainty: 0
#       }
#       stop_id: "PF_N04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 28
#       arrival {
#         time: 1721321151
#         uncertainty: 0
#       }
#       stop_id: "PF_N06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 29
#       arrival {
#         time: 1721321296
#         uncertainty: 0
#       }
#       stop_id: "PF_N07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 30
#       arrival {
#         time: 1721321459
#         uncertainty: 0
#       }
#       stop_id: "PF_N08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 31
#       arrival {
#         time: 1721321717
#         uncertainty: 0
#       }
#       stop_id: "PF_N09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 32
#       arrival {
#         time: 1721321975
#         uncertainty: 0
#       }
#       stop_id: "PF_N10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 33
#       arrival {
#         time: 1721322278
#         uncertainty: 0
#       }
#       stop_id: "PF_N11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 34
#       arrival {
#         time: 1721322517
#         uncertainty: 0
#       }
#       stop_id: "PF_N12_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "350"
#       label: "630"
#       license_plate: "8_7194-7195.7475-7474.7322-7323.7263-7262"
#     }
#     timestamp: 1721322045
#   }
# }
# entity {
#   id: "138"
#   trip_update {
#     trip {
#       trip_id: "6216858_19920"
#       start_time: "12:35:00"
#       start_date: "20240718"
#       schedule_relationship: CANCELED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#   }
# }
# entity {
#   id: "139"
#   trip_update {
#     trip {
#       trip_id: "6216862_19920"
#       start_time: "12:14:00"
#       start_date: "20240718"
#       schedule_relationship: CANCELED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#   }
# }
# entity {
#   id: "140"
#   trip_update {
#     trip {
#       trip_id: "6216788_19920"
#       start_time: "11:39:00"
#       start_date: "20240718"
#       schedule_relationship: CANCELED
#       route_id: "YELLOW"
#       direction_id: 0
#     }
#   }
# }
# entity {
#   id: "141"
#   trip_update {
#     trip {
#       trip_id: "6218025_19920"
#       start_time: "11:34:00"
#       start_date: "20240718"
#       schedule_relationship: CANCELED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#   }
# }

# %% [markdown]
# __Get Service Alerts__ - stop moved, unforeseen events affecting a station, route or the entire network

# %%
response = requests.get("https://api.wmata.com/gtfs/rail-gtfsrt-alerts.pb", headers=header) 
alerts_pb = rt.FeedMessage()
alerts_pb.ParseFromString(response.content)
alerts_pb
# Out:
# header {
#   gtfs_realtime_version: "2.0"
#   incrementality: FULL_DATASET
#   timestamp: 1721322039
# }
# entity {
#   id: "8f43ec6d-fa1f-ef11-840a-0022481ee669"
#   alert {
#     informed_entity {
#       route_id: "RED"
#     }
#     cause: MAINTENANCE
#     effect: SIGNIFICANT_DELAYS
#     url {
#       translation {
#         text: ""
#         language: "en-us"
#       }
#     }
#     header_text {
#       translation {
#         text: "Shuttle buses replace trains between Glenmont & Takoma for summer construction work through August 31st. Info: wmata.com"
#         language: "en-us"
#       }
#     }
#     description_text {
#       translation {
#         text: "Shuttle buses replace trains between Glenmont & Takoma for summer construction work through August 31st. Info: wmata.com"
#         language: "en-us"
#       }
#     }
#   }
# }
# entity {
#   id: "e2df0838-fb1f-ef11-840a-0022481ee669"
#   alert {
#     informed_entity {
#       route_id: "RED"
#     }
#     cause: MAINTENANCE
#     effect: SIGNIFICANT_DELAYS
#     url {
#       translation {
#         text: ""
#         language: "en-us"
#       }
#     }
#     header_text {
#       translation {
#         text: "Glenmont, Wheaton, Forest Glen & Silver Spring stations are closed for summer construction work through August 31st. Info: https://www.wmata.com"
#         language: "en-us"
#       }
#     }
#     description_text {
#       translation {
#         text: "Glenmont, Wheaton, Forest Glen & Silver Spring stations are closed for summer construction work through August 31st. Info: https://www.wmata.com"
#         language: "en-us"
#       }
#     }
#   }
# }

# %% [markdown]
# __Real-Time Rail Predictions__ - WMATA also provides realtime predictions in the API, which is probably what they use for their next train screens at the stations. This data is updated every 20-30s.

# %%
response = requests.get("https://api.wmata.com/StationPrediction.svc/json/GetPrediction/All", headers=header) 
rt_predictions_json = response.json()
rt_predictions_arr = rt_predictions_json["Trains"]
rt_predictions = pd.DataFrame.from_records(rt_predictions_arr)
rt_predictions
# Out:
#       Car  Destination DestinationCode  \
# 0       6  Shady Grove            None
# 1       8       Takoma             B07
# 2       8       Takoma             B07
# 3       6    Shady Grv            None
# 4       8       Takoma             B07
# ..    ...          ...             ...
# 537     6       Dulles             N10
# 538     -        Largo             G05
# 539  None      ssenger            None
# 540  None      ssenger            None
# 541  None      ssenger            None
#
#                              DestinationName Group Line LocationCode  \
# 0                                Shady Grove     2   RD          A01
# 1                                     Takoma     1   RD          A06
# 2                                     Takoma     1   RD          A08
# 3                                  Shady Grv     2   RD          A09
# 4                                     Takoma     1   RD          A10
# ..                                       ...   ...  ...          ...
# 537  Washington Dulles International Airport     2   SV          N09
# 538                           Downtown Largo     1   SV          N09
# 539                             No Passenger     2   No          B08
# 540                             No Passenger     2   No          B09
# 541                             No Passenger     1   No          E01
#
#                               LocationName  Min
# 0                             Metro Center  BRD
# 1                             Van Ness-UDC  BRD
# 2                       Friendship Heights  BRD
# 3                                 Bethesda  BRD
# 4                           Medical Center  BRD
# ..                                     ...  ...
# 537                      Innovation Center   33
# 538                      Innovation Center   35
# 539                          Silver Spring
# 540                            Forest Glen  ---
# 541  Mt Vernon Sq 7th St-Convention Center  ---
#
# [542 rows x 9 columns]

# %% [markdown]
# # What Affects WMATA's Predicted Arrival Times?

# %% [markdown]
# This will be a test of coordinating real-time data from multiple http requests. The goal is to pull all of the relevant data at the same time (approx. 1:30 pm on 7/9/2024) (each request may take a few seconds, but for our purposes we'll consider this simultaneous), collect it into a dataframe, and visualize the relationships between the various independent variables and the WMATA system's predicted arrival time for a given train. We're kind of doing data science _on_ data science, since we're analyzing the effects of variables on the results of a predictive model.
#
# - Goal 1: plot arrival predictions vs nearest train distance

# %% [markdown]
# ### Effect of Nearest Train Distance on Predicted Arrival Times

# %% [markdown]
# How close is the nearest train coming our way on X line? And how does this distance affect the arrival time predicted by DC's metro system? The answer may be obvious, but the relationship may not be as straight-cut or linear as we assume, so let's make some plots.

# %%
# collect vehicle position data into a dataframe
positions_arr = []
for entity in positions_pb.entity:
    if entity.HasField('vehicle'):
        positions_arr.append([entity.vehicle.position.latitude, entity.vehicle.position.longitude, entity.vehicle.position.bearing, 
                              entity.vehicle.vehicle.id, entity.vehicle.trip.trip_id, entity.vehicle.trip.route_id, entity.vehicle.trip.direction_id, entity.vehicle.stop_id])
        
rt_positions = pd.DataFrame(positions_arr, columns=['latitude', 'longitude', 'bearing', 'vehicle_id', 'trip_id', 'route_id', 'direction_id', 'stop_id'])
rt_positions
# Out:
#      latitude  longitude  bearing vehicle_id        trip_id route_id  \
# 0   39.120907 -77.165367    145.0        260  5952135_19920      RED
# 1   38.942280 -77.062485    156.0        259  5952229_19920      RED
# 2   39.084236 -77.146248    138.0        254  5952230_19920      RED
# 3   39.047127 -77.112465    159.0        290  5952054_19920      RED
# 4   38.997330 -77.096725    175.0        280  5951951_19920      RED
# ..        ...        ...      ...        ...            ...      ...
# 86  38.923763 -77.211945    240.0        453  6216874_19920   SILVER
# 87  38.947884 -77.340286    293.0        251  6216784_19920   SILVER
# 88  38.961632 -77.452263    180.0        350  6216869_19920   SILVER
# 89  38.948067 -76.871925     42.0        422  6217959_19920   ORANGE
# 90  38.826759 -76.911781    129.0        370  6216854_19920    GREEN
#
#     direction_id   stop_id
# 0              0  PF_A15_C
# 1              0  PF_A06_C
# 2              0  PF_A14_C
# 3              0  PF_A12_C
# 4              0  PF_A10_C
# ..           ...       ...
# 86             1  PF_N01_C
# 87             1  PF_N06_C
# 88             1  PF_N10_C
# 89             0  PF_D13_C
# 90             1  PF_F11_C
#
# [91 rows x 8 columns]

# %% [markdown]
# Note that there are around 90 trains active in the system. This number fluctuates when we re-request the data because it is updated in real time.

# %% [markdown]
# The difficulty lies in connecting each arrival time prediction to the the nearest train in the same line, on the same track, going the right direction. Each prediction has a station code, line, and destination code. The trips.txt file links destinations to train_ids and trip_ids, so we could get all the train_ids that correspond to a given predictions' destination. The problem is, this will also get trains that are already past our station, which should not be included in our calculation of the nearest train.

# %% [markdown]
# To illustrate this issue, __say we're at Fort Totten (station code E06) and trying to take the green line south__ (to L'Enfant, or wherever). We need our train to not just be going the right direction, it must also not already be past Fort Totten. To filter to only those trains that we can catch, we need each train's stop_id, telling us where it is in the line.

# %% [markdown]
# <center><img src="dc_metro_map_green.png"/></center>

# %%
# Get all trips on a line going the same direction
going_to_branch_ave = trips[(trips['route_id'] == 'GREEN') & (trips['direction_id'] == 1)]
# get all active gree line trains to BRANCH AVE 
trips_to_branch_ave = rt_positions[rt_positions['trip_id'].isin(going_to_branch_ave['trip_id'])]
trips_to_branch_ave
# Out:
#      latitude  longitude  bearing vehicle_id        trip_id route_id  \
# 69  39.010387 -76.911919    215.0        255  6217374_19920    GREEN
# 70  38.952370 -76.985947    276.0        325  6216856_19920    GREEN
# 71  38.985245 -76.925491    199.0        342  6216840_19920    GREEN
# 72  38.931602 -77.028877    246.0        364  6217373_19920    GREEN
# 75  38.893227 -77.021973    180.0        301  6216855_19920    GREEN
# 76  38.863274 -76.995628    167.0        450  6216851_19920    GREEN
# 77  38.851070 -76.956589     80.0        292  6217372_19920    GREEN
# 78  38.844635 -76.932915    139.0        272  6216853_19920    GREEN
# 90  38.826759 -76.911781    129.0        370  6216854_19920    GREEN
#
#     direction_id   stop_id
# 69             1  PF_E10_C
# 70             1  PF_E07_2
# 71             1  PF_E10_C
# 72             1  PF_E05_C
# 75             1  PF_F02_C
# 76             1  PF_F06_C
# 77             1  PF_F09_C
# 78             1  PF_F10_C
# 90             1  PF_F11_C

# %% [markdown]
# These are all the active trains going south on the green line. But if we're at Fort Totten, we can't get to the trains that are already south of us. We need to know the current station_id of each train to filter these out. I wrote a function in util.py that determines if a train is catchable to us base on our station id, its station id, and its direction.

# %%
# Each stop has a parent station, unless it is a parent station, then the field is filled with 'NaN' (which is type float)
# fill in these values with the station's own ID so we can use parent_id for every stop
for index, row in stops.iterrows():
    if type(row['parent_station']) == float:
        stops.at[index, 'parent_station'] = stops.at[index, 'stop_id']

# THIS WILL NEED TO BE REVISED, IT IS HIDEOUS
# Add station_id to branch ave trips(trains), this gives the current location of the train
trips_to_branch_ave['station_id'] = pd.Series()
for index, row in trips_to_branch_ave.iterrows():
    parent_station = stops['parent_station'][stops['stop_id'] == trips_to_branch_ave.at[index, 'stop_id']].iloc[0][4:]
    if len(parent_station) > 3: 
         trips_to_branch_ave.at[index, 'station_id']
    trips_to_branch_ave.at[index, 'station_id'] = stops['parent_station'][stops['stop_id'] == trips_to_branch_ave.at[index, 'stop_id']].iloc[0][4:]
# Out:
# /tmp/ipykernel_75/2774635542.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trips_to_branch_ave['station_id'] = pd.Series()

# %%
trips_to_branch_ave
# Out:
#      latitude  longitude  bearing vehicle_id        trip_id route_id  \
# 69  39.010387 -76.911919    215.0        255  6217374_19920    GREEN
# 70  38.952370 -76.985947    276.0        325  6216856_19920    GREEN
# 71  38.985245 -76.925491    199.0        342  6216840_19920    GREEN
# 72  38.931602 -77.028877    246.0        364  6217373_19920    GREEN
# 75  38.893227 -77.021973    180.0        301  6216855_19920    GREEN
# 76  38.863274 -76.995628    167.0        450  6216851_19920    GREEN
# 77  38.851070 -76.956589     80.0        292  6217372_19920    GREEN
# 78  38.844635 -76.932915    139.0        272  6216853_19920    GREEN
# 90  38.826759 -76.911781    129.0        370  6216854_19920    GREEN
#
#     direction_id   stop_id station_id
# 69             1  PF_E10_C        E10
# 70             1  PF_E07_2        E07
# 71             1  PF_E10_C        E10
# 72             1  PF_E05_C        E05
# 75             1  PF_F02_C        F02
# 76             1  PF_F06_C        F06
# 77             1  PF_F09_C        F09
# 78             1  PF_F10_C        F10
# 90             1  PF_F11_C        F11

# %%
import util;

# %%
trips_to_branch_ave['catchable'] = pd.Series()
for index, row in trips_to_branch_ave.iterrows():
    trips_to_branch_ave.at[index, 'catchable'] = util.is_catchable("E06", "GR", 1, row['station_id'])
# Out:
# /tmp/ipykernel_75/2191244077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trips_to_branch_ave['catchable'] = pd.Series()

# %%
trips_to_branch_ave
# Out:
#      latitude  longitude  bearing vehicle_id        trip_id route_id  \
# 69  39.010387 -76.911919    215.0        255  6217374_19920    GREEN
# 70  38.952370 -76.985947    276.0        325  6216856_19920    GREEN
# 71  38.985245 -76.925491    199.0        342  6216840_19920    GREEN
# 72  38.931602 -77.028877    246.0        364  6217373_19920    GREEN
# 75  38.893227 -77.021973    180.0        301  6216855_19920    GREEN
# 76  38.863274 -76.995628    167.0        450  6216851_19920    GREEN
# 77  38.851070 -76.956589     80.0        292  6217372_19920    GREEN
# 78  38.844635 -76.932915    139.0        272  6216853_19920    GREEN
# 90  38.826759 -76.911781    129.0        370  6216854_19920    GREEN
#
#     direction_id   stop_id station_id catchable
# 69             1  PF_E10_C        E10     False
# 70             1  PF_E07_2        E07     False
# 71             1  PF_E10_C        E10     False
# 72             1  PF_E05_C        E05     False
# 75             1  PF_F02_C        F02     False
# 76             1  PF_F06_C        F06     False
# 77             1  PF_F09_C        F09     False
# 78             1  PF_F10_C        F10     False
# 90             1  PF_F11_C        F11     False

# %%
our_station_id = "B08" #(Silver Spring)
line = 'RD'
direction = 0 # to glenmont
train_station_id = "A13" #(glenmont)

util.is_catchable(our_station_id, line, direction, train_station_id)
# Out:
# False

# %% [markdown]
# #### Prediction destination -> line & direction

# %% [markdown]
# ### AVG minimum wait time at a station for each hour in a day
