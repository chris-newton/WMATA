# %%
import requests, zipfile, io, sys
import pandas as pd

# %% [markdown]
# # Data Collection & EDA

# %% [markdown]
# __a. Lines Information__

# %%
header = {'api_key': '29f3d28264f8450f96506480de622a24'}
response = requests.get("https://api.wmata.com/Rail.svc/json/jLines", headers=header) 
response.status_code
# Out:
# 200

# %%
lines_json = response.json()
lines_arr = lines_json["Lines"]
lines = pd.DataFrame.from_records(lines_arr)
lines
# Out:
#   LineCode DisplayName StartStationCode EndStationCode InternalDestination1  \
# 0       BL        Blue              J03            G05
# 1       GR       Green              F11            E10
# 2       OR      Orange              K08            D13
# 3       RD         Red              A15            B11                  A11
# 4       SV      Silver              N06            G05
# 5       YL      Yellow              C15            E06                  E01
#
#   InternalDestination2
# 0
# 1
# 2
# 3                  B08
# 4
# 5

# %% [markdown]
# __b. Stations Information__

# %%
r = requests.get("https://api.wmata.com/Rail.svc/json/jStations", headers=header) 
r.status_code
# Out:
# 200

# %%
stations_json = r.json()
stations_arr = stations_json["Stations"]
stations = pd.DataFrame.from_records(stations_arr)
stations.to_csv('out.csv')

# %% [markdown]
# The address data is nested in a dict. Let's give each field in the dict a new column.

# %%
addresses = stations['Address'].apply(pd.Series)
stations = pd.concat([stations.drop(['Address'], axis=1), addresses], axis=1)
stations[:1]
# Out:
#   Code          Name StationTogether1 StationTogether2 LineCode1 LineCode2  \
# 0  A01  Metro Center              C01                         RD      None
#
#   LineCode3 LineCode4        Lat        Lon           Street        City  \
# 0      None      None  38.898303 -77.028099  607 13th St. NW  Washington
#
#   State    Zip
# 0    DC  20005

# %%
stations[stations['StationTogether1'] != '']
# Out:
#    Code                  Name StationTogether1 StationTogether2 LineCode1  \
# 0   A01          Metro Center              C01                         RD
# 15  B01  Gallery Pl-Chinatown              F01                         RD
# 20  B06           Fort Totten              E06                         RD
# 27  C01          Metro Center              A01                         BL
# 44  D03        L'Enfant Plaza              F03                         BL
# 60  E06           Fort Totten              B06                         GR
# 65  F01  Gallery Pl-Chinatown              B01                         GR
# 67  F03        L'Enfant Plaza              D03                         GR
#
#    LineCode2 LineCode3 LineCode4        Lat        Lon  \
# 0       None      None      None  38.898303 -77.028099
# 15      None      None      None  38.898340 -77.021851
# 20      None      None      None  38.951777 -77.002174
# 27        OR        SV      None  38.898303 -77.028099
# 44        OR        SV      None  38.884775 -77.021964
# 60        YL      None      None  38.951777 -77.002174
# 65        YL      None      None  38.898340 -77.021851
# 67        YL      None      None  38.884775 -77.021964
#
#                     Street        City State    Zip
# 0          607 13th St. NW  Washington    DC  20005
# 15            630 H St. NW  Washington    DC  20001
# 20      550 Galloway St NE  Washington    DC  20011
# 27         607 13th St. NW  Washington    DC  20005
# 44  600 Maryland Avenue SW  Washington    DC  20024
# 60      550 Galloway St NE  Washington    DC  20011
# 65            630 H St. NW  Washington    DC  20001
# 67  600 Maryland Avenue SW  Washington    DC  20024

# %%
stations[stations['StationTogether1'] != ''].shape
# Out:
# (8, 14)

# %% [markdown]
# There are 8 stations with more than one entrance.

# %%
stations.shape
# Out:
# (102, 14)

# %% [markdown]
# Note that there are 102 metro stations respresented in our dataset.

# %% [markdown]
# __c. Station to Station__

# %%
r = requests.get("https://api.wmata.com/Rail.svc/json/jSrcStationToDstStationInfo", headers=header) 
r.status_code
# Out:
# 200

# %%
station_to_station_json = r.json()
station_to_station_arr = station_to_station_json["StationToStationInfos"]
station_to_station = pd.DataFrame.from_records(station_to_station_arr)
station_to_station.head()
# Out:
#   SourceStation DestinationStation  CompositeMiles  RailTime  \
# 0           A01                A02            0.75         2
# 1           A01                A03            1.23         4
# 2           A01                A04            2.40         6
# 3           A01                A05            3.10         9
# 4           A01                A06            3.73        11
#
#                                             RailFare
# 0  {'PeakTime': 2.0, 'OffPeakTime': 2.0, 'SeniorD...
# 1  {'PeakTime': 2.25, 'OffPeakTime': 2.25, 'Senio...
# 2  {'PeakTime': 2.25, 'OffPeakTime': 2.25, 'Senio...
# 3  {'PeakTime': 2.3, 'OffPeakTime': 2.3, 'SeniorD...
# 4  {'PeakTime': 2.6, 'OffPeakTime': 2.5, 'SeniorD...

# %% [markdown]
# The fare data is nested in a dict with three fields: _OffPeakTime_, _PeakTime_, and _SeniorDisabled_. Let's put them in their own columns.

# %%
fares = station_to_station['RailFare'].apply(pd.Series)
station_to_station = pd.concat([station_to_station.drop(['RailFare'], axis=1), fares], axis=1)
station_to_station.head()
# Out:
#   SourceStation DestinationStation  CompositeMiles  RailTime  PeakTime  \
# 0           A01                A02            0.75         2      2.00
# 1           A01                A03            1.23         4      2.25
# 2           A01                A04            2.40         6      2.25
# 3           A01                A05            3.10         9      2.30
# 4           A01                A06            3.73        11      2.60
#
#    OffPeakTime  SeniorDisabled
# 0         2.00            1.10
# 1         2.25            1.10
# 2         2.25            1.10
# 3         2.30            1.15
# 4         2.50            1.25

# %% [markdown]
# Note that there are 10,300 rows for station to station info. The station to station info should have a row for each combination of stations, including both directions separately (routes __A -> B__ _and_ __B -> A__ should both be counted because their fares/times may differ). The number of combinations of 2 stations out of 102 total is calculated with the combinations formula (nCr), and comes out to 5151, which is half of 10,300 (minus 2 missing rows for combinations of the same station (A -> A)).

# %% [markdown]
# So 10,300 is the number of possible combinations of stations in the system, including _some_ of the combinations of a station and itself. Note that there is a real fare for "routes" from a station to itself, meaning that users are actually charged for entering and then exiting the same station. In 2016, WMATA implemented a grace period that would refund users if they leave the station in 15 minutes.

# %% [markdown]
# __d. GTFS Static__

# %% [markdown]
# The GTFS (General Transit Feed Specification) is an open standard data format used by WMATA to store its more in-depth transit data. We can retrieve data such as real-time ridership, train locations, speeds, and service alerts, which is the stuff we'll need to do some real data science.

# %% [markdown]
# First I'm trying to get the static (non real-time) version of the data. It is updated daily, so still plenty useful for analysis

# %%
response = requests.get("https://api.wmata.com/gtfs/rail-gtfs-static.zip", headers=header) 
response.status_code
# Out:
# 200

# %%
z = zipfile.ZipFile(io.BytesIO(response.content))
z.extractall(path='./gtfs_static') # extract the data to './gtfs_static'

# %%
trips = pd.read_csv('./gtfs_static/trips.txt')
stops = pd.read_csv('./gtfs_static/stops.txt')

# %% [markdown]
# __e. GTFS Real Time__

# %%
import google.protobuf
import gtfs_realtime_pb2 as rt

# %% [markdown]
# This is a protocol format file we need to set up our system to be able to read the data from the protocol buffer file. I'll compile the protocol buffer into the CWD

# %%
response = requests.get("https://gtfs.org/realtime/gtfs-realtime.proto") 
# !protoc -I=. --python_out=. ./gtfs-realtime.proto

# %% [markdown]
# __Get Vehicle Positions__ - the real-time lattitude, longitude, bearing, occupancy status and more for each train in the system

# %%
response = requests.get("https://api.wmata.com/gtfs/rail-gtfsrt-vehiclepositions.pb", headers=header) 
positions_pb = rt.FeedMessage()
positions_pb.ParseFromString(response.content)
positions_pb
# Out:
# header {
#   gtfs_realtime_version: "2.0"
#   incrementality: FULL_DATASET
#   timestamp: 1720807600
# }
# entity {
#   id: "0"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952350_19913"
#       start_time: "14:09:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.1198959
#       longitude: -77.1647339
#       bearing: 148
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_A15_C"
#     vehicle {
#       id: "462"
#       label: "135"
#       license_plate: "8_7540-7541.7187-7186.7460-7461.7703-7702"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "1"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952635_19913"
#       start_time: "13:33:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9171944
#       longitude: -77.0469589
#       bearing: 159
#     }
#     current_stop_sequence: 12
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_A04_C"
#     vehicle {
#       id: "419"
#       label: "123"
#       license_plate: "6_3156-3157.3204-3205.3188-3189"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "2"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952493_19913"
#       start_time: "13:39:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9464188
#       longitude: -77.0775909
#       bearing: 114
#     }
#     current_stop_sequence: 9
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_A07_C"
#     vehicle {
#       id: "434"
#       label: "125"
#       license_plate: "8_3197-3196.3151-3150.3179-3178.3263-3262"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "3"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952461_19913"
#       start_time: "13:49:48"
#       start_date: "20240712"
#       schedule_relationship: DUPLICATED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.0164833
#       longitude: -77.1008301
#       bearing: 152
#     }
#     current_stop_sequence: 5
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_A11_C"
#     vehicle {
#       id: "445"
#       label: "129"
#       license_plate: "6_3144-3145.3229-3228.3275-3274"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "4"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952461_19913"
#       start_time: "14:03:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.0514374
#       longitude: -77.1142578
#       bearing: 174
#     }
#     current_stop_sequence: 3
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_A13_C"
#     vehicle {
#       id: "450"
#       label: "131"
#       license_plate: "8_7002-7003.7059-7058.7026-7027.7079-7078"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "5"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952461_19913"
#       start_time: "13:52:11"
#       start_date: "20240712"
#       schedule_relationship: DUPLICATED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.0891838
#       longitude: -77.1502075
#       bearing: 159
#     }
#     current_stop_sequence: 1
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_A15_C"
#     vehicle {
#       id: "055"
#       label: "133"
#       license_plate: "6_3259-3258.3131-3130.3182-3183"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "6"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952459_19913"
#       start_time: "13:58:23"
#       start_date: "20240712"
#       schedule_relationship: DUPLICATED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9848862
#       longitude: -77.0943451
#       bearing: 165
#     }
#     current_stop_sequence: 6
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_A10_C"
#     vehicle {
#       id: "152"
#       label: "127"
#       license_plate: "8_"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "7"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952371_19913"
#       start_time: "14:07:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9759979
#       longitude: -77.0181885
#       bearing: 156
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_B07_C"
#     vehicle {
#       id: "386"
#       label: "144"
#       license_plate: "8_7048-7049.7091-7090.7074-7075.7077-7076"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "8"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR431"
#       start_time: "14:03:31"
#       start_date: "20240712"
#       schedule_relationship: ADDED
#       route_id: "NR"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9886
#       longitude: -77.0260239
#       bearing: 146
#     }
#     timestamp: 1720807600
#     vehicle {
#       id: "289"
#       label: "PM57"
#       license_plate: "0_"
#     }
#   }
# }
# entity {
#   id: "9"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952576_19913"
#       start_time: "13:49:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8983421
#       longitude: -77.0275574
#       bearing: 270
#     }
#     current_stop_sequence: 9
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_A01_2"
#     vehicle {
#       id: "397"
#       label: "138"
#       license_plate: "6_3248-3249.3163-3162.3118-3119"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "10"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952639_19913"
#       start_time: "14:01:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9517746
#       longitude: -77.0022278
#       bearing: 163
#     }
#     current_stop_sequence: 2
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_B06_C"
#     vehicle {
#       id: "431"
#       label: "142"
#       license_plate: "6_3239-3238.3235-3234.3203-3202"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "11"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR101"
#       start_time: "14:04:41"
#       start_date: "20240712"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 1
#     }
#     position {
#       latitude: 39.0021
#       longitude: -77.0402679
#       bearing: 179
#     }
#     timestamp: 1720807600
#     vehicle {
#       id: "101"
#       label: ""
#       license_plate: "0_"
#     }
#   }
# }
# entity {
#   id: "12"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952520_19913"
#       start_time: "13:55:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8990211
#       longitude: -77.0069885
#       bearing: 196
#     }
#     current_stop_sequence: 5
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_B35_C"
#     vehicle {
#       id: "090"
#       label: "140"
#       license_plate: "6_3241-3240.3123-3122.3266-3267"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "13"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952370_19913"
#       start_time: "13:43:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9099159
#       longitude: -77.0435715
#       bearing: 336
#     }
#     current_stop_sequence: 11
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_A03_2"
#     vehicle {
#       id: "492"
#       label: "136"
#       license_plate: "6_3209-3208.3286-3287.3272-3273"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "14"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952481_19913"
#       start_time: "13:37:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9463387
#       longitude: -77.0724411
#       bearing: 270
#     }
#     current_stop_sequence: 14
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_A06_C"
#     vehicle {
#       id: "392"
#       label: "134"
#       license_plate: "6_3276-3277.3180-3181.3175-3174"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "15"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952634_19913"
#       start_time: "13:31:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9742775
#       longitude: -77.0897751
#       bearing: 352
#     }
#     current_stop_sequence: 16
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_A08_C"
#     vehicle {
#       id: "479"
#       label: "132"
#       license_plate: "6_3223-3222.3159-3158.3236-3237"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "16"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952560_19913"
#       start_time: "13:25:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 39.0297508
#       longitude: -77.1040573
#       bearing: 339
#     }
#     current_stop_sequence: 19
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_A11_C"
#     vehicle {
#       id: "472"
#       label: "130"
#       license_plate: "8_7022-7023.7005-7004.7018-7019.7081-7080"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "17"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952369_19913"
#       start_time: "13:19:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 39.05896
#       longitude: -77.1167755
#       bearing: 318
#     }
#     current_stop_sequence: 20
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_A12_C"
#     vehicle {
#       id: "471"
#       label: "128"
#       license_plate: "8_3250-3251.3192-3193.3185-3184.3146-3147"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "18"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952519_19913"
#       start_time: "13:13:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 1
#     }
#     position {
#       latitude: 39.106472
#       longitude: -77.1565247
#       bearing: 344
#     }
#     current_stop_sequence: 22
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_A14_C"
#     vehicle {
#       id: "384"
#       label: "126"
#       license_plate: "8_7046-7047.7011-7010.7720-7721.7043-7042"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "19"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952651_19913"
#       start_time: "13:27:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8947754
#       longitude: -77.0131073
#       bearing: 92
#     }
#     current_stop_sequence: 17
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_B02_1"
#     vehicle {
#       id: "409"
#       label: "121"
#       license_plate: "8_7054-7055.7095-7094.7696-7697.7031-7030"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "20"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952457_19913"
#       start_time: "13:21:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9209
#       longitude: -76.9958725
#       bearing: 18
#     }
#     current_stop_sequence: 20
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_B04_C"
#     vehicle {
#       id: "402"
#       label: "119"
#       license_plate: "8_3074-3075.3148-3149.3195-3194.3230-3231"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "21"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952580_19913"
#       start_time: "13:15:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9534225
#       longitude: -77.002739
#       bearing: 343
#     }
#     current_stop_sequence: 22
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_B06_C"
#     vehicle {
#       id: "395"
#       label: "117"
#       license_plate: "8_7086-7087.7061-7060.7070-7071.7065-7064"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "22"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR323"
#       start_time: "03:10:43"
#       start_date: "20240712"
#       schedule_relationship: ADDED
#       route_id: "NR"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9800873
#       longitude: -77.0204315
#       bearing: 337
#     }
#     current_stop_sequence: 1
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_B07_C"
#     vehicle {
#       id: "333"
#       label: "PM41"
#       license_plate: "0_"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "23"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR018"
#       start_time: "12:12:47"
#       start_date: "20240712"
#       schedule_relationship: ADDED
#       route_id: "NR"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.0136223
#       longitude: -77.0422592
#       bearing: 347
#     }
#     timestamp: 1720807600
#     vehicle {
#       id: "353"
#       label: ""
#       license_plate: "0_"
#     }
#   }
# }
# entity {
#   id: "24"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177736_19913"
#       start_time: "14:13:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8773079
#       longitude: -77.2737274
#       bearing: 78
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_K08_C"
#     vehicle {
#       id: "121"
#       label: "903"
#       license_plate: "8_"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "25"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177155_19913"
#       start_time: "14:11:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.0058937
#       longitude: -77.4920502
#       bearing: 321
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_N12_C"
#     vehicle {
#       id: "141"
#       label: "605"
#       license_plate: "6_7382-7383.7328-7329.7617-7616"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "26"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178745_19913"
#       start_time: "14:02:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.7992363
#       longitude: -77.1292572
#       bearing: 80
#     }
#     current_stop_sequence: 2
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_J02_C"
#     vehicle {
#       id: "374"
#       label: "449"
#       license_plate: "8_7212-7213.7499-7498.7568-7569.7153-7152"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "27"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177970_19913"
#       start_time: "13:35:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9204216
#       longitude: -77.223732
#       bearing: 85
#     }
#     current_stop_sequence: 9
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_N03_C"
#     vehicle {
#       id: "376"
#       label: "649"
#       license_plate: "8_7230-7231.7121-7120.7534-7535.7269-7268"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "28"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177954_19913"
#       start_time: "13:59:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9557343
#       longitude: -77.4490204
#       bearing: 90
#     }
#     current_stop_sequence: 3
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_N10_C"
#     vehicle {
#       id: "413"
#       label: "603"
#       license_plate: "6_7406-7407.7148-7149.7415-7414"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "29"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177756_19913"
#       start_time: "13:49:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8822403
#       longitude: -77.1132126
#       bearing: 88
#     }
#     current_stop_sequence: 5
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_K04_1"
#     vehicle {
#       id: "437"
#       label: "949"
#       license_plate: "8_7684-7685.7320-7321.7183-7182.7459-7458"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "30"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177966_19913"
#       start_time: "13:11:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9008446
#       longitude: -77.0461731
#       bearing: 70
#     }
#     current_stop_sequence: 18
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_C04_C"
#     vehicle {
#       id: "453"
#       label: "645"
#       license_plate: "6_7618-7619.7308-7309.7333-7332"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "31"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177961_19913"
#       start_time: "13:23:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8798141
#       longitude: -77.1385727
#       bearing: 112
#     }
#     current_stop_sequence: 12
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_K05_C"
#     vehicle {
#       id: "481"
#       label: "647"
#       license_plate: "6_7350-7351.7663-7662.7215-7214"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "32"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177755_19913"
#       start_time: "13:37:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.898632
#       longitude: -77.0281677
#       bearing: 180
#     }
#     current_stop_sequence: 13
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_C01_C"
#     vehicle {
#       id: "025"
#       label: "947"
#       license_plate: "6_7164-7165.7110-7111.7167-7166"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "33"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178744_19913"
#       start_time: "13:50:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8398361
#       longitude: -77.0477371
#       bearing: 129
#     }
#     current_stop_sequence: 5
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_C11_1"
#     vehicle {
#       id: "046"
#       label: "447"
#       license_plate: "8_7602-7603.7723-7722.7196-7197.7551-7550"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "34"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177953_19913"
#       start_time: "13:47:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9522
#       longitude: -77.356308
#       bearing: 103
#     }
#     current_stop_sequence: 6
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_N07_C"
#     vehicle {
#       id: "094"
#       label: "601"
#       license_plate: "8_7490-7491.7501-7500.7652-7653.7623-7622"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "35"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178748_19913"
#       start_time: "13:38:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8594971
#       longitude: -77.0596
#       bearing: 347
#     }
#     current_stop_sequence: 7
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_C09_1"
#     vehicle {
#       id: "100"
#       label: "445"
#       license_plate: "6_7686-7687.7605-7604.7665-7664"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "36"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177757_19913"
#       start_time: "14:01:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8904457
#       longitude: -77.2114792
#       bearing: 53
#     }
#     current_stop_sequence: 2
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_K07_C"
#     vehicle {
#       id: "104"
#       label: "901"
#       license_plate: "6_3020-3021.3063-3062.3054-3055"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "37"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177813_19913"
#       start_time: "14:10:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9486656
#       longitude: -76.871048
#       bearing: 222
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_D13_C"
#     vehicle {
#       id: "432"
#       label: "910"
#       license_plate: "8_7744-7745.7257-7256.7430-7431.7743-7742"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "38"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178741_19913"
#       start_time: "14:06:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.896431
#       longitude: -76.8530884
#       bearing: 266
#     }
#     current_stop_sequence: 1
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_G05_C"
#     vehicle {
#       id: "385"
#       label: "402"
#       license_plate: "8_7726-7727.7661-7660.7680-7681.7517-7516"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "39"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177956_19913"
#       start_time: "13:38:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8851128
#       longitude: -77.014389
#       bearing: 273
#     }
#     current_stop_sequence: 9
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_D05_C"
#     vehicle {
#       id: "405"
#       label: "602"
#       license_plate: "6_6175-6174.6158-6159.6103-6102"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "40"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177811_19913"
#       start_time: "13:46:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.881321
#       longitude: -76.9855804
#       bearing: 270
#     }
#     current_stop_sequence: 7
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_D07_C"
#     vehicle {
#       id: "411"
#       label: "906"
#       license_plate: "6_3025-3024.3033-3032.3041-3040"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "41"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177098_19913"
#       start_time: "14:02:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8867874
#       longitude: -76.8925629
#       bearing: 270
#     }
#     current_stop_sequence: 2
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_G04_C"
#     vehicle {
#       id: "440"
#       label: "606"
#       license_plate: "8_7210-7211.7473-7472.7632-7633.7135-7134"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "42"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177948_19913"
#       start_time: "13:50:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8869247
#       longitude: -76.9771423
#       bearing: 180
#     }
#     current_stop_sequence: 6
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_D08_C"
#     vehicle {
#       id: "470"
#       label: "604"
#       license_plate: "8_7468-7469.7159-7158.7634-7635.7589-7588"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "43"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178749_19913"
#       start_time: "13:42:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8851547
#       longitude: -76.9972153
#       bearing: 298
#     }
#     current_stop_sequence: 8
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_D06_C"
#     vehicle {
#       id: "474"
#       label: "446"
#       license_plate: "6_7506-7507.7565-7564.7747-7746"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "44"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177816_19913"
#       start_time: "13:58:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9007149
#       longitude: -76.94487
#       bearing: 226
#     }
#     current_stop_sequence: 4
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_D10_C"
#     vehicle {
#       id: "494"
#       label: "908"
#       license_plate: "6_3068-3069.3291-3290.3053-3052"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "45"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178740_19913"
#       start_time: "13:54:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8955879
#       longitude: -76.9495392
#       bearing: 288
#     }
#     current_stop_sequence: 5
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_G01_C"
#     vehicle {
#       id: "027"
#       label: "448"
#       license_plate: "8_6059-6058.6029-6028.6071-6070.6095-6094"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "46"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR135"
#       start_time: "13:36:37"
#       start_date: "20240712"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9013596
#       longitude: -77.0317535
#       bearing: 270
#     }
#     current_stop_sequence: 14
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_C01_C"
#     vehicle {
#       id: "135"
#       label: "824"
#       license_plate: "6_7502-7503.7393-7392.7609-7608"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "47"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177810_19913"
#       start_time: "13:34:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9013596
#       longitude: -77.0404663
#       bearing: 270
#     }
#     current_stop_sequence: 16
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_C03_2"
#     vehicle {
#       id: "393"
#       label: "904"
#       license_plate: "8_3039-3038.3116-3117.3079-3078.3093-3092"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "48"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178739_19913"
#       start_time: "13:30:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8960304
#       longitude: -77.0709076
#       bearing: 178
#     }
#     current_stop_sequence: 18
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_C05_2"
#     vehicle {
#       id: "396"
#       label: "444"
#       license_plate: "6_7484-7485.7378-7379.7405-7404"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "49"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177901_19913"
#       start_time: "14:11:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.7938232
#       longitude: -77.0752258
#       bearing: 7
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_C15_C"
#     vehicle {
#       id: "483"
#       label: "349"
#       license_plate: "6_6150-6151.6031-6030.6068-6069"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "50"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6176916_19913"
#       start_time: "14:03:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8065681
#       longitude: -77.0609283
#       bearing: 49
#     }
#     current_stop_sequence: 3
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_C13_C"
#     vehicle {
#       id: "459"
#       label: "347"
#       license_plate: "8_7198-7199.7531-7530.7250-7251.7733-7732"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "51"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177905_19913"
#       start_time: "13:55:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8535347
#       longitude: -77.0440598
#       bearing: 342
#     }
#     current_stop_sequence: 6
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_C10_1"
#     vehicle {
#       id: "465"
#       label: "345"
#       license_plate: "6_3110-3111.3085-3084.3051-3050"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "52"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178756_19913"
#       start_time: "13:18:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8700562
#       longitude: -77.0530777
#       bearing: 226
#     }
#     current_stop_sequence: 19
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_C06_2"
#     vehicle {
#       id: "161"
#       label: "442"
#       license_plate: "6_7162-7163.7354-7355.7205-7204"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "53"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177930_19913"
#       start_time: "14:04:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8987923
#       longitude: -77.0219803
#       bearing: 180
#     }
#     current_stop_sequence: 2
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_F01_C"
#     vehicle {
#       id: "429"
#       label: "304"
#       license_plate: "6_7698-7699.7394-7395.7157-7156"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "54"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177927_19913"
#       start_time: "13:56:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8728027
#       longitude: -77.0410767
#       bearing: 215
#     }
#     current_stop_sequence: 4
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_F03_2"
#     vehicle {
#       id: "415"
#       label: "302"
#       license_plate: "6_6033-6032.6098-6099.6143-6142"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "55"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177927_19913"
#       start_time: "13:53:11"
#       start_date: "20240712"
#       schedule_relationship: DUPLICATED
#       route_id: "YELLOW"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8630028
#       longitude: -77.0593872
#       bearing: 186
#     }
#     current_stop_sequence: 5
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_C07_2"
#     vehicle {
#       id: "408"
#       label: "348"
#       license_plate: "8_6165-6164.6015-6014.6122-6123.6063-6062"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "56"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178758_19913"
#       start_time: "13:03:14"
#       start_date: "20240712"
#       schedule_relationship: DUPLICATED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8060493
#       longitude: -77.0619
#       bearing: 229
#     }
#     current_stop_sequence: 26
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_C13_C"
#     vehicle {
#       id: "114"
#       label: "440"
#       license_plate: "8_7736-7737.7591-7590.7504-7505.7729-7728"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "57"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177928_19913"
#       start_time: "13:40:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.7992401
#       longitude: -77.0725403
#       bearing: 223
#     }
#     current_stop_sequence: 12
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_C14_2"
#     vehicle {
#       id: "399"
#       label: "346"
#       license_plate: "8_7532-7533.7445-7444.7574-7575.7637-7636"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "58"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178747_19913"
#       start_time: "13:26:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8847885
#       longitude: -77.0220871
#       bearing: 90
#     }
#     current_stop_sequence: 18
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_D03_C"
#     vehicle {
#       id: "447"
#       label: "443"
#       license_plate: "6_7712-7713.7344-7345.7279-7278"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "59"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177966_19913"
#       start_time: "12:46:29"
#       start_date: "20240712"
#       schedule_relationship: DUPLICATED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8852768
#       longitude: -76.9977951
#       bearing: 115
#     }
#     current_stop_sequence: 26
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_D05_C"
#     vehicle {
#       id: "381"
#       label: "643"
#       license_plate: "8_7316-7317.7227-7226.7184-7185.7109-7108"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "60"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177754_19913"
#       start_time: "13:25:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8820038
#       longitude: -76.9897614
#       bearing: 118
#     }
#     current_stop_sequence: 19
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_D06_C"
#     vehicle {
#       id: "407"
#       label: "945"
#       license_plate: "6_7734-7735.7103-7102.7417-7416"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "61"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177971_19913"
#       start_time: "12:59:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8887558
#       longitude: -76.9769745
#       bearing: 11
#     }
#     current_stop_sequence: 29
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_D08_C"
#     vehicle {
#       id: "107"
#       label: "641"
#       license_plate: "6_6162-6163.6086-6087.6126-6127"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "62"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178778_19913"
#       start_time: "13:48:59"
#       start_date: "20240712"
#       schedule_relationship: DUPLICATED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8835564
#       longitude: -76.9776154
#       bearing: 39
#     }
#     current_stop_sequence: 22
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_D07_C"
#     vehicle {
#       id: "144"
#       label: "441"
#       license_plate: "6_7724-7725.7181-7180.7625-7624"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "63"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177753_19913"
#       start_time: "13:13:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9166222
#       longitude: -76.9166489
#       bearing: 67
#     }
#     current_stop_sequence: 24
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_D11_1"
#     vehicle {
#       id: "387"
#       label: "943"
#       license_plate: "6_7336-7337.7708-7709.7595-7594"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "64"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177958_19913"
#       start_time: "14:09:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8267593
#       longitude: -76.9117813
#       bearing: 309
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_F11_C"
#     vehicle {
#       id: "420"
#       label: "547"
#       license_plate: "8_6021-6020.6024-6025.6084-6085.6093-6092"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "65"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177965_19913"
#       start_time: "14:01:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8509827
#       longitude: -76.9579544
#       bearing: 260
#     }
#     current_stop_sequence: 3
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_F09_C"
#     vehicle {
#       id: "476"
#       label: "545"
#       license_plate: "8_7672-7673.7581-7580.7612-7613.7739-7738"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "66"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177957_19913"
#       start_time: "13:45:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8917961
#       longitude: -77.021843
#       bearing: 0
#     }
#     current_stop_sequence: 9
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_F03_1"
#     vehicle {
#       id: "388"
#       label: "541"
#       license_plate: "8_6157-6156.6079-6078.6011-6010.6125-6124"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "67"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6176918_19913"
#       start_time: "13:47:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8710518
#       longitude: -77.0444946
#       bearing: 89
#     }
#     current_stop_sequence: 9
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_C07_1"
#     vehicle {
#       id: "442"
#       label: "343"
#       license_plate: "6_6012-6013.6141-6140.6047-6046"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "68"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177897_19913"
#       start_time: "13:39:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "YELLOW"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8979683
#       longitude: -77.0218353
#       bearing: 0
#     }
#     current_stop_sequence: 12
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_F01_C"
#     vehicle {
#       id: "091"
#       label: "341"
#       license_plate: "6_6042-6043.6074-6075.6121-6120"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "69"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177048_19913"
#       start_time: "13:53:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8633
#       longitude: -76.995491
#       bearing: 347
#     }
#     current_stop_sequence: 6
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_F06_C"
#     vehicle {
#       id: "508"
#       label: "543"
#       license_plate: "8_7642-7643.7495-7494.7688-7689.7693-7692"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "70"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177232_19913"
#       start_time: "14:10:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 39.0103874
#       longitude: -76.9119186
#       bearing: 215
#     }
#     current_stop_sequence: 1
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_E10_C"
#     vehicle {
#       id: "511"
#       label: "504"
#       license_plate: "8_7366-7367.7247-7246.7572-7573.7143-7142"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "71"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177009_19913"
#       start_time: "13:54:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.951786
#       longitude: -77.0032043
#       bearing: 265
#     }
#     current_stop_sequence: 5
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_E06_C"
#     vehicle {
#       id: "389"
#       label: "548"
#       license_plate: "8_6149-6148.6112-6113.6167-6166.6009-6008"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "72"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177910_19913"
#       start_time: "14:02:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9716492
#       longitude: -76.932724
#       bearing: 250
#     }
#     current_stop_sequence: 2
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_E09_C"
#     vehicle {
#       id: "469"
#       label: "502"
#       license_plate: "6_7536-7537.7670-7671.7561-7560"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "73"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177911_19913"
#       start_time: "13:46:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9169579
#       longitude: -77.0275192
#       bearing: 90
#     }
#     current_stop_sequence: 8
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_E03_C"
#     vehicle {
#       id: "498"
#       label: "546"
#       license_plate: "8_6118-6119.6090-6091.6004-6005.6144-6145"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "74"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177951_19913"
#       start_time: "13:37:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9170609
#       longitude: -77.0275192
#       bearing: 270
#     }
#     current_stop_sequence: 14
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_E03_C"
#     vehicle {
#       id: "454"
#       label: "539"
#       license_plate: "6_7556-7557.7658-7659.7189-7188"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "75"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177047_19913"
#       start_time: "13:29:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9519806
#       longitude: -76.9826431
#       bearing: 96
#     }
#     current_stop_sequence: 17
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_E06_C"
#     vehicle {
#       id: "443"
#       label: "537"
#       license_plate: "6_7614-7615.7127-7126.7235-7234"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "76"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR128"
#       start_time: "13:22:29"
#       start_date: "20240712"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9728508
#       longitude: -76.9306183
#       bearing: 34
#     }
#     current_stop_sequence: 19
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_E08_1"
#     vehicle {
#       id: "128"
#       label: "812"
#       license_plate: "6_6041-6040.6016-6017"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "77"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177935_19913"
#       start_time: "13:21:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9850388
#       longitude: -76.9255295
#       bearing: 19
#     }
#     current_stop_sequence: 20
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_E09_C"
#     vehicle {
#       id: "417"
#       label: "535"
#       license_plate: "6_7576-7577.7679-7678.7587-7586"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "78"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177934_19913"
#       start_time: "13:38:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8835487
#       longitude: -77.0219345
#       bearing: 180
#     }
#     current_stop_sequence: 13
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_F03_2"
#     vehicle {
#       id: "455"
#       label: "544"
#       license_plate: "6_7552-7553.7648-7649.7601-7600"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "79"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177005_19913"
#       start_time: "13:30:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8555794
#       longitude: -76.9940567
#       bearing: 177
#     }
#     current_stop_sequence: 16
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_F06_C"
#     vehicle {
#       id: "452"
#       label: "542"
#       license_plate: "6_6178-6179.6001-6000.6006-6007"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "80"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR115"
#       start_time: "13:36:32"
#       start_date: "20240712"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8500252
#       longitude: -76.9614792
#       bearing: 61
#     }
#     current_stop_sequence: 15
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_F08_C"
#     vehicle {
#       id: "115"
#       label: "796"
#       license_plate: "6_3132-3133.3014-3015.3172-3173"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "81"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177923_19913"
#       start_time: "13:22:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8503151
#       longitude: -76.9446487
#       bearing: 129
#     }
#     current_stop_sequence: 19
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_F09_C"
#     vehicle {
#       id: "012"
#       label: "540"
#       license_plate: "8_6147-6146.6152-6153.6035-6034.6138-6139"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "82"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177915_19913"
#       start_time: "13:14:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "GREEN"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8342285
#       longitude: -76.9188
#       bearing: 148
#     }
#     current_stop_sequence: 20
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_F10_C"
#     vehicle {
#       id: "005"
#       label: "538"
#       license_plate: "6_7272-7273.7429-7428.7571-7570"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "83"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178754_19913"
#       start_time: "13:02:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8874741
#       longitude: -76.884758
#       bearing: 72
#     }
#     current_stop_sequence: 26
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_G03_C"
#     vehicle {
#       id: "410"
#       label: "439"
#       license_plate: "8_7674-7675.7656-7657.7509-7508.7481-7480"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "84"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177967_19913"
#       start_time: "13:37:13"
#       start_date: "20240712"
#       schedule_relationship: DUPLICATED
#       route_id: "SILVER"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.8983917
#       longitude: -76.8473282
#       bearing: 46
#     }
#     current_stop_sequence: 33
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_G04_C"
#     vehicle {
#       id: "136"
#       label: "639"
#       license_plate: "8_7682-7683.7451-7450.7538-7539.7467-7466"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "85"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6178758_19913"
#       start_time: "13:06:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8037567
#       longitude: -77.1105881
#       bearing: 237
#     }
#     current_stop_sequence: 26
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_C13_C"
#     vehicle {
#       id: "148"
#       label: "438"
#       license_plate: "6_3027-3026.3269-3268.3072-3073"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "86"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177972_19913"
#       start_time: "13:26:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8918304
#       longitude: -77.0804749
#       bearing: 264
#     }
#     current_stop_sequence: 18
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_C05_2"
#     vehicle {
#       id: "404"
#       label: "648"
#       license_plate: "6_7348-7349.7457-7456.7651-7650"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "87"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177809_19913"
#       start_time: "13:22:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8902168
#       longitude: -77.0871277
#       bearing: 243
#     }
#     current_stop_sequence: 19
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_K01_C"
#     vehicle {
#       id: "072"
#       label: "902"
#       license_plate: "8_7124-7125.7629-7628.7510-7511.7669-7668"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "88"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177962_19913"
#       start_time: "13:14:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8860779
#       longitude: -77.1569214
#       bearing: 294
#     }
#     current_stop_sequence: 23
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_K05_C"
#     vehicle {
#       id: "087"
#       label: "646"
#       license_plate: "8_7324-7325.7583-7582.7620-7621.7191-7190"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "89"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177807_19913"
#       start_time: "13:10:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "ORANGE"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.8959923
#       longitude: -77.2019501
#       bearing: 233
#     }
#     current_stop_sequence: 24
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_K06_2"
#     vehicle {
#       id: "497"
#       label: "948"
#       license_plate: "6_3048-3049.3090-3091.3060-3061"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "90"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177952_19913"
#       start_time: "13:02:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9237633
#       longitude: -77.2119446
#       bearing: 240
#     }
#     current_stop_sequence: 24
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_N01_C"
#     vehicle {
#       id: "111"
#       label: "644"
#       license_plate: "6_7258-7259.7694-7695.7435-7434"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "91"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177946_19913"
#       start_time: "12:50:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9478836
#       longitude: -77.3402863
#       bearing: 293
#     }
#     current_stop_sequence: 28
#     current_status: INCOMING_AT
#     timestamp: 1720807600
#     stop_id: "PF_N06_C"
#     vehicle {
#       id: "010"
#       label: "642"
#       license_plate: "8_7118-7119.7529-7528.7420-7421.7513-7512"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "92"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177969_19913"
#       start_time: "12:38:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9527245
#       longitude: -77.3814621
#       bearing: 85
#     }
#     current_stop_sequence: 29
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_N07_C"
#     vehicle {
#       id: "038"
#       label: "640"
#       license_plate: "6_6027-6026.6180-6181.6105-6104"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "93"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR464"
#       start_time: "10:20:33"
#       start_date: "20240712"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.0104
#       longitude: -77.4960556
#       bearing: 145
#     }
#     timestamp: 1720807600
#     vehicle {
#       id: "464"
#       label: "744"
#       license_plate: "8_"
#     }
#   }
# }
# entity {
#   id: "94"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "6177949_19913"
#       start_time: "12:26:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     position {
#       latitude: 38.9952812
#       longitude: -77.474411
#       bearing: 117
#     }
#     current_stop_sequence: 33
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_N11_C"
#     vehicle {
#       id: "451"
#       label: "638"
#       license_plate: "6_7140-7141.7241-7240.7223-7222"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "95"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "5952466_19913"
#       start_time: "13:09:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     position {
#       latitude: 38.9760437
#       longitude: -77.0180588
#       bearing: 336
#     }
#     current_stop_sequence: 23
#     current_status: STOPPED_AT
#     timestamp: 1720807600
#     stop_id: "PF_B07_C"
#     vehicle {
#       id: "391"
#       label: "115"
#       license_plate: "8_7098-7099.7083-7082.7218-7219.7597-7596"
#     }
#     occupancy_status: EMPTY
#   }
# }
# entity {
#   id: "96"
#   is_deleted: false
#   vehicle {
#     trip {
#       trip_id: "NR036"
#       start_time: "14:06:40"
#       start_date: "20240712"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 0
#     }
#     position {
#       latitude: 39.0385
#       longitude: -77.0502472
#       bearing: 346
#     }
#     current_stop_sequence: 1
#     current_status: IN_TRANSIT_TO
#     timestamp: 1720807600
#     stop_id: "PF_B10_C"
#     vehicle {
#       id: "036"
#       label: ""
#       license_plate: "0_"
#     }
#     occupancy_status: EMPTY
#   }
# }

# %% [markdown]
# __Get Trip Updates__ - any fluctuation in the timetable (delays, cancellations, changed routes)

# %%
response = requests.get("https://api.wmata.com/gtfs/rail-gtfsrt-tripupdates.pb", headers=header) 
updates_pb = rt.FeedMessage()
updates_pb.ParseFromString(response.content)
updates_pb
# Out:
# header {
#   gtfs_realtime_version: "2.0"
#   incrementality: FULL_DATASET
#   timestamp: 1720807600
# }
# entity {
#   id: "0"
#   trip_update {
#     trip {
#       trip_id: "5952350_19913"
#       start_time: "14:09:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720807740
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720807930
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720808124
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720808270
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720808427
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720808630
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720808756
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720808931
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720809048
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720809202
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720809307
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720809429
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720809574
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720809678
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720809803
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720809892
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720809993
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720810109
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720810249
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720810401
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720810537
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720810696
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720810877
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "462"
#       label: "135"
#       license_plate: "8_7540-7541.7187-7186.7460-7461.7703-7702"
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "1"
#   trip_update {
#     trip {
#       trip_id: "5952568_19913"
#       start_time: "14:15:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720808100
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720808292
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720808486
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720808632
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720808789
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720808992
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720809118
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720809293
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720809410
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720809564
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720809669
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720809791
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720809936
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720810040
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720810165
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720810254
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720810355
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720810471
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720810611
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720810763
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720810899
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720811058
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720811239
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1551300"
#       label: "137"
#       license_plate: ""
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "2"
#   trip_update {
#     trip {
#       trip_id: "5952486_19913"
#       start_time: "14:21:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720808460
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720808650
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720808844
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720808990
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720809147
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720809350
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720809476
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720809651
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720809768
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720809922
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720810027
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720810149
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720810294
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720810398
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720810523
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720810612
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720810713
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720810829
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720810969
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720811121
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720811257
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720811416
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720811597
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1551660"
#       label: "139"
#       license_plate: ""
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "3"
#   trip_update {
#     trip {
#       trip_id: "5952612_19913"
#       start_time: "14:27:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720808820
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720809010
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720809204
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720809350
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720809507
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720809710
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720809836
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720810011
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720810128
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720810282
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720810387
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720810509
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720810654
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720810758
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720810883
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720810972
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720811073
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720811189
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720811329
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720811481
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720811617
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720811776
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720811957
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1552020"
#       label: "141"
#       license_plate: ""
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "4"
#   trip_update {
#     trip {
#       trip_id: "5952360_19913"
#       start_time: "14:33:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720809180
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720809370
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720809564
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720809710
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720809867
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720810070
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720810196
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720810371
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720810488
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720810642
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720810747
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720810869
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720811014
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720811118
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720811243
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720811332
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720811433
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720811549
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720811689
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720811841
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720811977
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720812136
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720812317
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1552380"
#       label: "143"
#       license_plate: ""
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "5"
#   trip_update {
#     trip {
#       trip_id: "5952636_19913"
#       start_time: "14:39:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720809540
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720809730
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720809924
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720810070
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720810227
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720810430
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720810556
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720810731
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720810848
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720811002
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720811107
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720811229
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720811374
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720811478
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720811603
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720811692
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720811793
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720811909
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720812049
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720812201
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720812337
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720812496
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720812677
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1552740"
#       label: "145"
#       license_plate: ""
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "6"
#   trip_update {
#     trip {
#       trip_id: "5952653_19913"
#       start_time: "14:45:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720809900
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720810090
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720810284
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720810430
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720810587
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720810790
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720810916
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720811091
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720811208
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720811362
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720811467
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720811589
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720811734
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720811838
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720811963
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720812052
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720812153
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720812269
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720812409
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720812561
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720812697
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720812856
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720813037
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "A1553100"
#       label: "147"
#       license_plate: ""
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "7"
#   trip_update {
#     trip {
#       trip_id: "5952635_19913"
#       start_time: "13:33:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720805648
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720805912
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720806131
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720806283
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720806457
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720806695
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720806830
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720807016
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720807133
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720807283
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720807397
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720807558
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720807654
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720807758
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720807883
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720807972
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720808073
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720808189
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720808329
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720808481
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720808617
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720808776
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720808957
#         uncertainty: 1357
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "419"
#       label: "123"
#       license_plate: "6_3156-3157.3204-3205.3188-3189"
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "8"
#   trip_update {
#     trip {
#       trip_id: "5952493_19913"
#       start_time: "13:39:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720805957
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720806216
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720806400
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720806545
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720806697
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720806909
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720807041
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720807336
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720807582
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720807681
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720807786
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720807908
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720808053
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720808157
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720808282
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720808371
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720808472
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720808588
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720808728
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720808880
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720809016
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720809175
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720809356
#         uncertainty: 1756
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "434"
#       label: "125"
#       license_plate: "8_3197-3196.3151-3150.3179-3178.3263-3262"
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "9"
#   trip_update {
#     trip {
#       trip_id: "5952461_19913"
#       start_time: "13:49:48"
#       start_date: "20240712"
#       schedule_relationship: DUPLICATED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720806730
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720806962
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720807144
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720807283
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720807477
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720807685
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720807811
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720807986
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720808103
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720808257
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720808362
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720808484
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720808629
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720808733
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720808858
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720808947
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720809048
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720809164
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720809304
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720809456
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720809592
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720809751
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720809932
#         uncertainty: 2332
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "445"
#       label: "129"
#       license_plate: "6_3144-3145.3229-3228.3275-3274"
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "10"
#   trip_update {
#     trip {
#       trip_id: "5952461_19913"
#       start_time: "14:03:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720807070
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720807321
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720807529
#         uncertainty: 0
#       }
# ...
#       stop_sequence: 24
#       arrival {
#         time: 1720806470
#         uncertainty: 0
#       }
#       stop_id: "PF_N01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 25
#       arrival {
#         time: 1720806591
#         uncertainty: 0
#       }
#       stop_id: "PF_N02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 26
#       arrival {
#         time: 1720806732
#         uncertainty: 0
#       }
#       stop_id: "PF_N03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 27
#       arrival {
#         time: 1720806858
#         uncertainty: 0
#       }
#       stop_id: "PF_N04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 28
#       arrival {
#         time: 1720807329
#         uncertainty: 0
#       }
#       stop_id: "PF_N06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 29
#       arrival {
#         time: 1720807517
#         uncertainty: 0
#       }
#       stop_id: "PF_N07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 30
#       arrival {
#         time: 1720807619
#         uncertainty: 0
#       }
#       stop_id: "PF_N08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 31
#       arrival {
#         time: 1720807809
#         uncertainty: 0
#       }
#       stop_id: "PF_N09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 32
#       arrival {
#         time: 1720808036
#         uncertainty: 0
#       }
#       stop_id: "PF_N10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 33
#       arrival {
#         time: 1720808366
#         uncertainty: 0
#       }
#       stop_id: "PF_N11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 34
#       arrival {
#         time: 1720808605
#         uncertainty: 0
#       }
#       stop_id: "PF_N12_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "038"
#       label: "640"
#       license_plate: "6_6027-6026.6180-6181.6105-6104"
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "137"
#   trip_update {
#     trip {
#       trip_id: "NR464"
#       start_time: "10:20:33"
#       start_date: "20240712"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720807622
#         uncertainty: 0
#       }
#       stop_id: "PF_N12_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "464"
#       label: "744"
#       license_plate: "8_"
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "138"
#   trip_update {
#     trip {
#       trip_id: "6177949_19913"
#       start_time: "12:26:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "SILVER"
#       direction_id: 1
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720801770
#         uncertainty: 0
#       }
#       stop_id: "PF_G05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720801950
#         uncertainty: 0
#       }
#       stop_id: "PF_G04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720802132
#         uncertainty: 0
#       }
#       stop_id: "PF_G03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720802266
#         uncertainty: 0
#       }
#       stop_id: "PF_G02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720802452
#         uncertainty: 0
#       }
#       stop_id: "PF_G01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720802751
#         uncertainty: 0
#       }
#       stop_id: "PF_D08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720802879
#         uncertainty: 0
#       }
#       stop_id: "PF_D07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720803056
#         uncertainty: 0
#       }
#       stop_id: "PF_D06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720803160
#         uncertainty: 0
#       }
#       stop_id: "PF_D05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720803279
#         uncertainty: 0
#       }
#       stop_id: "PF_D04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720803375
#         uncertainty: 0
#       }
#       stop_id: "PF_D03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720803486
#         uncertainty: 0
#       }
#       stop_id: "PF_D02_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720803595
#         uncertainty: 0
#       }
#       stop_id: "PF_D01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720803689
#         uncertainty: 0
#       }
#       stop_id: "PF_C01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720803803
#         uncertainty: 0
#       }
#       stop_id: "PF_C02_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720803888
#         uncertainty: 0
#       }
#       stop_id: "PF_C03_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720803999
#         uncertainty: 0
#       }
#       stop_id: "PF_C04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720804182
#         uncertainty: 0
#       }
#       stop_id: "PF_C05_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720804414
#         uncertainty: 0
#       }
#       stop_id: "PF_K01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720804512
#         uncertainty: 0
#       }
#       stop_id: "PF_K02_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720804618
#         uncertainty: 0
#       }
#       stop_id: "PF_K03_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720804735
#         uncertainty: 0
#       }
#       stop_id: "PF_K04_2"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720804969
#         uncertainty: 0
#       }
#       stop_id: "PF_K05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 24
#       arrival {
#         time: 1720805386
#         uncertainty: 0
#       }
#       stop_id: "PF_N01_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 25
#       arrival {
#         time: 1720805512
#         uncertainty: 0
#       }
#       stop_id: "PF_N02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 26
#       arrival {
#         time: 1720805651
#         uncertainty: 0
#       }
#       stop_id: "PF_N03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 27
#       arrival {
#         time: 1720805788
#         uncertainty: 0
#       }
#       stop_id: "PF_N04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 28
#       arrival {
#         time: 1720806286
#         uncertainty: 0
#       }
#       stop_id: "PF_N06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 29
#       arrival {
#         time: 1720806443
#         uncertainty: 0
#       }
#       stop_id: "PF_N07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 30
#       arrival {
#         time: 1720806642
#         uncertainty: 0
#       }
#       stop_id: "PF_N08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 31
#       arrival {
#         time: 1720806970
#         uncertainty: 0
#       }
#       stop_id: "PF_N09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 32
#       arrival {
#         time: 1720807222
#         uncertainty: 0
#       }
#       stop_id: "PF_N10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 33
#       arrival {
#         time: 1720807535
#         uncertainty: 0
#       }
#       stop_id: "PF_N11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 34
#       arrival {
#         time: 1720807721
#         uncertainty: 0
#       }
#       stop_id: "PF_N12_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "451"
#       label: "638"
#       license_plate: "6_7140-7141.7241-7240.7223-7222"
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "139"
#   trip_update {
#     trip {
#       trip_id: "5952466_19913"
#       start_time: "13:09:00"
#       start_date: "20240712"
#       schedule_relationship: SCHEDULED
#       route_id: "RED"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       departure {
#         time: 1720804187
#         uncertainty: 0
#       }
#       stop_id: "PF_A15_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 2
#       arrival {
#         time: 1720804431
#         uncertainty: 0
#       }
#       stop_id: "PF_A14_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 3
#       arrival {
#         time: 1720804656
#         uncertainty: 0
#       }
#       stop_id: "PF_A13_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 4
#       arrival {
#         time: 1720804807
#         uncertainty: 0
#       }
#       stop_id: "PF_A12_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 5
#       arrival {
#         time: 1720804963
#         uncertainty: 0
#       }
#       stop_id: "PF_A11_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 6
#       arrival {
#         time: 1720805186
#         uncertainty: 0
#       }
#       stop_id: "PF_A10_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 7
#       arrival {
#         time: 1720805320
#         uncertainty: 0
#       }
#       stop_id: "PF_A09_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 8
#       arrival {
#         time: 1720805492
#         uncertainty: 0
#       }
#       stop_id: "PF_A08_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 9
#       arrival {
#         time: 1720805613
#         uncertainty: 0
#       }
#       stop_id: "PF_A07_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 10
#       arrival {
#         time: 1720805776
#         uncertainty: 0
#       }
#       stop_id: "PF_A06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 11
#       arrival {
#         time: 1720805899
#         uncertainty: 0
#       }
#       stop_id: "PF_A05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 12
#       arrival {
#         time: 1720806000
#         uncertainty: 0
#       }
#       stop_id: "PF_A04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 13
#       arrival {
#         time: 1720806149
#         uncertainty: 0
#       }
#       stop_id: "PF_A03_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 14
#       arrival {
#         time: 1720806264
#         uncertainty: 0
#       }
#       stop_id: "PF_A02_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 15
#       arrival {
#         time: 1720806389
#         uncertainty: 0
#       }
#       stop_id: "PF_A01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 16
#       arrival {
#         time: 1720806461
#         uncertainty: 0
#       }
#       stop_id: "PF_B01_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 17
#       arrival {
#         time: 1720806537
#         uncertainty: 0
#       }
#       stop_id: "PF_B02_1"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 18
#       arrival {
#         time: 1720806677
#         uncertainty: 0
#       }
#       stop_id: "PF_B03_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 19
#       arrival {
#         time: 1720806807
#         uncertainty: 0
#       }
#       stop_id: "PF_B35_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 20
#       arrival {
#         time: 1720806986
#         uncertainty: 0
#       }
#       stop_id: "PF_B04_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 21
#       arrival {
#         time: 1720807106
#         uncertainty: 0
#       }
#       stop_id: "PF_B05_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 22
#       arrival {
#         time: 1720807409
#         uncertainty: 0
#       }
#       stop_id: "PF_B06_C"
#       schedule_relationship: SCHEDULED
#     }
#     stop_time_update {
#       stop_sequence: 23
#       arrival {
#         time: 1720807600
#         uncertainty: 0
#       }
#       stop_id: "PF_B07_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "391"
#       label: "115"
#       license_plate: "8_7098-7099.7083-7082.7218-7219.7597-7596"
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "140"
#   trip_update {
#     trip {
#       trip_id: "NR036"
#       start_time: "14:06:40"
#       start_date: "20240712"
#       schedule_relationship: UNSCHEDULED
#       route_id: "NR"
#       direction_id: 0
#     }
#     stop_time_update {
#       stop_sequence: 1
#       arrival {
#         time: 1720807600
#         uncertainty: 0
#       }
#       stop_id: "PF_B10_C"
#       schedule_relationship: SCHEDULED
#     }
#     vehicle {
#       id: "036"
#       label: ""
#       license_plate: "0_"
#     }
#     timestamp: 1720807600
#   }
# }
# entity {
#   id: "141"
#   trip_update {
#     trip {
#       trip_id: "6176991_19913"
#       start_time: "13:48:00"
#       start_date: "20240712"
#       schedule_relationship: CANCELED
#       route_id: "YELLOW"
#       direction_id: 1
#     }
#   }
# }
# entity {
#   id: "142"
#   trip_update {
#     trip {
#       trip_id: "5952544_19913"
#       start_time: "13:57:00"
#       start_date: "20240712"
#       schedule_relationship: CANCELED
#       route_id: "RED"
#       direction_id: 0
#     }
#   }
# }
# entity {
#   id: "143"
#   trip_update {
#     trip {
#       trip_id: "6178755_19913"
#       start_time: "13:14:00"
#       start_date: "20240712"
#       schedule_relationship: CANCELED
#       route_id: "BLUE"
#       direction_id: 0
#     }
#   }
# }
# entity {
#   id: "144"
#   trip_update {
#     trip {
#       trip_id: "6178759_19913"
#       start_time: "12:54:00"
#       start_date: "20240712"
#       schedule_relationship: CANCELED
#       route_id: "BLUE"
#       direction_id: 1
#     }
#   }
# }
# entity {
#   id: "145"
#   trip_update {
#     trip {
#       trip_id: "6177751_19913"
#       start_time: "12:49:00"
#       start_date: "20240712"
#       schedule_relationship: CANCELED
#       route_id: "ORANGE"
#       direction_id: 0
#     }
#   }
# }

# %% [markdown]
# __Get Service Alerts__ - stop moved, unforeseen events affecting a station, route or the entire network

# %%
response = requests.get("https://api.wmata.com/gtfs/rail-gtfsrt-alerts.pb", headers=header) 
alerts_pb = rt.FeedMessage()
alerts_pb.ParseFromString(response.content)
alerts_pb
# Out:
# header {
#   gtfs_realtime_version: "2.0"
#   incrementality: FULL_DATASET
#   timestamp: 1720807594
# }
# entity {
#   id: "8f43ec6d-fa1f-ef11-840a-0022481ee669"
#   alert {
#     informed_entity {
#       route_id: "RED"
#     }
#     cause: MAINTENANCE
#     effect: SIGNIFICANT_DELAYS
#     url {
#       translation {
#         text: ""
#         language: "en-us"
#       }
#     }
#     header_text {
#       translation {
#         text: "Shuttle buses replace trains between Glenmont & Takoma for summer construction work through August 31st. Info: wmata.com"
#         language: "en-us"
#       }
#     }
#     description_text {
#       translation {
#         text: "Shuttle buses replace trains between Glenmont & Takoma for summer construction work through August 31st. Info: wmata.com"
#         language: "en-us"
#       }
#     }
#   }
# }
# entity {
#   id: "e2df0838-fb1f-ef11-840a-0022481ee669"
#   alert {
#     informed_entity {
#       route_id: "RED"
#     }
#     cause: MAINTENANCE
#     effect: SIGNIFICANT_DELAYS
#     url {
#       translation {
#         text: ""
#         language: "en-us"
#       }
#     }
#     header_text {
#       translation {
#         text: "Glenmont, Wheaton, Forest Glen & Silver Spring stations are closed for summer construction work through August 31st. Info: https://www.wmata.com"
#         language: "en-us"
#       }
#     }
#     description_text {
#       translation {
#         text: "Glenmont, Wheaton, Forest Glen & Silver Spring stations are closed for summer construction work through August 31st. Info: https://www.wmata.com"
#         language: "en-us"
#       }
#     }
#   }
# }

# %% [markdown]
# __Real-Time Rail Predictions__ - WMATA also provides realtime predictions in the API, which is probably what they use for their next train screens at the stations. This data is updated every 20-30s.

# %%
response = requests.get("https://api.wmata.com/StationPrediction.svc/json/GetPrediction/All", headers=header) 
rt_predictions_json = response.json()
rt_predictions_arr = rt_predictions_json["Trains"]
rt_predictions = pd.DataFrame.from_records(rt_predictions_arr)
rt_predictions
# Out:
#       Car  Destination DestinationCode     DestinationName Group Line  \
# 0       6  Shady Grove            None         Shady Grove     2   RD
# 1       6    Shady Grv            None           Shady Grv     2   RD
# 2       8    Shady Grv            None           Shady Grv     2   RD
# 3       8       Takoma             B07              Takoma     1   RD
# 4       8       Takoma             B07              Takoma     1   RD
# ..    ...          ...             ...                 ...   ...  ...
# 541     -       Vienna             K08  Vienna/Fairfax-GMU     2   OR
# 542     6        Largo             G05      Downtown Largo     1   SV
# 543     -        Largo             G05      Downtown Largo     1   SV
# 544  None      ssenger            None        No Passenger     1   No
# 545  None      ssenger            None        No Passenger     1   No
#
#     LocationCode                LocationName  Min
# 0            A01                Metro Center  BRD
# 1            A03               Dupont Circle  BRD
# 2            A11        Grosvenor-Strathmore  BRD
# 3            B04  Rhode Island Ave-Brentwood  BRD
# 4            B06                 Fort Totten  BRD
# ..           ...                         ...  ...
# 541          D10                    Deanwood   34
# 542          N03                  Greensboro   35
# 543          N07          Reston Town Center   35
# 544          B09                 Forest Glen
# 545          B10                     Wheaton  ---
#
# [546 rows x 9 columns]

# %% [markdown]
# # What Affects WMATA's Predicted Arrival Times?

# %% [markdown]
# This will be a test of coordinating real-time data from multiple http requests. The goal is to pull all of the relevant data at the same time (approx. 1:30 pm on 7/9/2024) (each request may take a few seconds, but for our purposes we'll consider this simultaneous), collect it into a dataframe, and visualize the relationships between the various independent variables and the WMATA system's predicted arrival time for a given train. We're kind of doing data science _on_ data science, since we're analyzing the effects of variables on the results of a predictive model.
#
# - Goal 1: plot arrival predictions vs nearest train distance

# %% [markdown]
# ### Effect of Nearest Train Distance on Predicted Arrival Times

# %% [markdown]
# How close is the nearest train coming our way on X line? And how does this distance affect the arrival time predicted by DC's metro system? The answer may be obvious, but the relationship may not be as straight-cut or linear as we assume, so let's make some plots.

# %%
# collect vehicle position data into a dataframe
positions_arr = []
for entity in positions_pb.entity:
    if entity.HasField('vehicle'):
        positions_arr.append([entity.vehicle.position.latitude, entity.vehicle.position.longitude, entity.vehicle.position.bearing, 
                              entity.vehicle.vehicle.id, entity.vehicle.trip.trip_id, entity.vehicle.trip.route_id, entity.vehicle.trip.direction_id, entity.vehicle.stop_id])
        
rt_positions = pd.DataFrame(positions_arr, columns=['latitude', 'longitude', 'bearing', 'vehicle_id', 'trip_id', 'route_id', 'direction_id', 'stop_id'])
rt_positions
# Out:
#      latitude  longitude  bearing vehicle_id        trip_id route_id  \
# 0   39.119896 -77.164734    148.0        462  5952350_19913      RED
# 1   38.917194 -77.046959    159.0        419  5952635_19913      RED
# 2   38.946419 -77.077591    114.0        434  5952493_19913      RED
# 3   39.016483 -77.100830    152.0        445  5952461_19913      RED
# 4   39.051437 -77.114258    174.0        450  5952461_19913      RED
# ..        ...        ...      ...        ...            ...      ...
# 92  38.952724 -77.381462     85.0        038  6177969_19913   SILVER
# 93  39.010399 -77.496056    145.0        464          NR464       NR
# 94  38.995281 -77.474411    117.0        451  6177949_19913   SILVER
# 95  38.976044 -77.018059    336.0        391  5952466_19913      RED
# 96  39.038502 -77.050247    346.0        036          NR036       NR
#
#     direction_id   stop_id
# 0              0  PF_A15_C
# 1              0  PF_A04_C
# 2              0  PF_A07_C
# 3              0  PF_A11_C
# 4              0  PF_A13_C
# ..           ...       ...
# 92             1  PF_N07_C
# 93             0
# 94             1  PF_N11_C
# 95             0  PF_B07_C
# 96             0  PF_B10_C
#
# [97 rows x 8 columns]

# %% [markdown]
# Note that there are around 90 trains active in the system. This number fluctuates when we re-request the data.

# %% [markdown]
# The difficulty lies in connecting each arrival time prediction to the the nearest train in the same line, on the same track, going the right direction. Each prediction has a station code, line, and destination code. The trips.txt file links destinations to train_ids and trip_ids, so we could get all the train_ids that correspond to a given predictions' destination. The problem is, this will also get trains that are already past our station, which should not be included in our calculation of the nearest train.

# %% [markdown]
# To illustrate this issue, __say we're at Fort Totten (station code E06) and trying to take the green line south__ (to L'Enfant, or wherever). We need our train to not just be going the right direction, it must also not already be past Fort Totten. To filter to only those trains that we can catch, we need each train's stop_id, telling us where it is in the line.

# %% [markdown]
# <center><img src="dc_metro_map_green.png"/></center>

# %%
trips[trips['trip_headsign'] == 'GLENMONT']
# Out:
#      route_id service_id        trip_id trip_headsign  direction_id  block_id  \
# 0         RED       75_R  5950543_19913      GLENMONT             0       NaN
# 1         RED       75_R  5950527_19913      GLENMONT             0       NaN
# 2         RED       75_R  5950556_19913      GLENMONT             0       NaN
# 3         RED       75_R  5950567_19913      GLENMONT             0       NaN
# 4         RED       75_R  5950552_19913      GLENMONT             0       NaN
# ...       ...        ...            ...           ...           ...       ...
# 1203      RED       78_R  5949659_19913      GLENMONT             0       NaN
# 1204      RED       78_R  5949665_19913      GLENMONT             0       NaN
# 1205      RED       78_R  5949670_19913      GLENMONT             0       NaN
# 1206      RED       78_R  5949750_19913      GLENMONT             0       NaN
# 1207      RED       78_R  5949643_19913      GLENMONT             0       NaN
#
#      shape_id  scheduled_trip_id train_id
# 0      RRED_1          5950543.0      124
# 1      RRED_1          5950527.0      125
# 2      RRED_1          5950556.0      126
# 3      RRED_1          5950567.0      127
# 4      RRED_1          5950552.0      101
# ...       ...                ...      ...
# 1203   RRED_8          5949659.0     1134
# 1204   RRED_8          5949665.0      127
# 1205   RRED_8          5949670.0      102
# 1206   RRED_8          5949750.0      104
# 1207   RRED_8          5949643.0      105
#
# [702 rows x 9 columns]

# %%
# Get all trips on a line going the same direction
going_to_branch_ave = trips[(trips['route_id'] == 'GREEN') & (trips['direction_id'] == 1)]
# get all active gree line trains to BRANCH AVE 
trips_to_branch_ave = rt_positions[rt_positions['trip_id'].isin(going_to_branch_ave['trip_id'])]
trips_to_branch_ave
# Out:
#      latitude  longitude  bearing vehicle_id        trip_id route_id  \
# 70  39.010387 -76.911919    215.0        511  6177232_19913    GREEN
# 71  38.951786 -77.003204    265.0        389  6177009_19913    GREEN
# 72  38.971649 -76.932724    250.0        469  6177910_19913    GREEN
# 73  38.916958 -77.027519     90.0        498  6177911_19913    GREEN
# 78  38.883549 -77.021935    180.0        455  6177934_19913    GREEN
# 79  38.855579 -76.994057    177.0        452  6177005_19913    GREEN
# 81  38.850315 -76.944649    129.0        012  6177923_19913    GREEN
# 82  38.834229 -76.918800    148.0        005  6177915_19913    GREEN
#
#     direction_id   stop_id
# 70             1  PF_E10_C
# 71             1  PF_E06_C
# 72             1  PF_E09_C
# 73             1  PF_E03_C
# 78             1  PF_F03_2
# 79             1  PF_F06_C
# 81             1  PF_F09_C
# 82             1  PF_F10_C

# %% [markdown]
# These are all the active trains going south on the green line. But if we're at Fort Totten, we can't get to the trains that are already south of us. We need to know the current station_id of each train to filter these out.

# %%
# Each stop has a parent station, unless it is a parent station, then the field is filled with 'NaN' (which is type float)
# fill in these values with the station's own ID so we can use parent_id for every stop
for index, row in stops.iterrows():
    if type(row['parent_station']) == float:
        stops.at[index, 'parent_station'] = stops.at[index, 'stop_id']

# %%
# THIS WILL NEED TO BE REVISED, IT IS HIDEOUS

# Add station_id to branch ave trips(trains), this gives the current location of the train
trips_to_branch_ave['station_id'] = pd.Series()
for index, row in trips_to_branch_ave.iterrows():
    trips_to_branch_ave.at[index, 'station_id'] = (stops['parent_station'][stops['stop_id'] == trips_to_branch_ave.at[index, 'stop_id']].iloc[0])
# Out:
# /tmp/ipykernel_76/2244675950.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trips_to_branch_ave['station_id'] = pd.Series()

# %%
import util;

# %%
stations[stations['Name'] == 'Glenmont']
# Out:
#    Code      Name StationTogether1 StationTogether2 LineCode1 LineCode2  \
# 25  B11  Glenmont                                          RD      None
#
#    LineCode3 LineCode4        Lat       Lon             Street           City  \
# 25      None      None  39.061713 -77.05341  12601 Georgia Ave  Silver Spring
#
#    State    Zip
# 25    MD  20906

# %% [markdown]
# TESTING is_catchable

# %%
our_station_id = "B08" #(Silver Spring)
line = 'RD'
direction = 0 # to glenmont
train_station_id = "B11" #(glenmont)

# %%
util.is_catchable(our_station_id, line, direction, train_station_id)
# Out:
# True

# %% [markdown]
# #### Prediction destination -> line & direction
